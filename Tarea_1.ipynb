# %% [markdown]
# # Tarea 1 Bases de Datos 2024-1 Grupo XX
#
# _Recuerde modificar esta celda y la siguiente! (Borre esta línea también)._

# %% [markdown]
# ## Integrantes:
# * Eduardo Pacheco - 202273014-5
# * Catalina Yanez - 202273010-2
# * Alex Dominguez - 202273012-9

# %% [markdown]
# ## Requisitos para Correr el Notebook
#
# Para poder utilizar este Notebook se debe tener instalado:
# - **Python 3**
# - **Jupyter**
# - La librería **ipython-sql** (Poder ejecutar sql en Jupyter Notebook)
# - PostgreSQL y su conector desde Python(**psycopg2**)
#
# **IMPORTANTE:** Este Jupyter Notebook se conectará a su servicio de Base de Datos PostgreSQL de manera **local**, por lo que **no funcionará correctamente en el entorno Google Collab.**
#
# Para instalar las dependencias, ejecute (**recuerde actualizar pip3**):

# %%
! pip3 install ipython-sql

! pip3 install psycopg2
# Out:
# Requirement already satisfied: ipython-sql in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (3.10.0)
# Requirement already satisfied: ipython in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (8.2.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (2.0.29)
# Requirement already satisfied: sqlparse in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (0.4.3)
# Requirement already satisfied: six in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.3)
# Requirement already satisfied: backcall in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.1.3)
# Requirement already satisfied: pickleshare in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (3.0.29)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (2.11.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (58.1.0)
# Requirement already satisfied: stack-data in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: colorama in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.4.4)
# Requirement already satisfied: wcwidth in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: executing in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: psycopg2 in c:\users\alexd\appdata\local\programs\python\python310\lib\site-packages (2.9.4)

# %% [markdown]
# ## Importar dependencias

# %%
import random
from datetime import datetime, timedelta

#Librerías para PostgreSQL
import psycopg2

# %% [markdown]
# Para conectarse a la base de datos, completen los datos relevantes en la variable DATABASE_URL.
#
# * Cambie `user` por el usuario que utilizó en Postgres para acceder a la Base de Datos. Por defecto `postgres`.
# * Cambie `password` por la contraseña de dicho usuario. **Recuerde borrarla antes de entregar su tarea.**
# * Cambie `port` por el puerto en que se ejecuta su servicio de Base de Datos. Por defecto `5432`.
# * Cambie `database` por el nombre de la BD (Schema) que creó en Postgres.
#
# Ejemplo: `postgresql://postgres:pass_segura@localhost:5432/tarea-bd`

# %%
# %reload_ext sql
# %env DATABASE_URL=postgresql://postgres:alexinho123@localhost:5432/Tarea_1_BD
# Out:
# env: DATABASE_URL=postgresql://postgres:alexinho123@localhost:5432/Tarea_1_BD

# %% [markdown]
# Para conectarse de forma declarativa a la Base de Datos, utilice el siguiente código:

# %%
#Recuerde cambiar los valores de USER, DBNAME y PASSWORD por los mismos de la celda superior.
conn = psycopg2.connect(
   host="localhost",
   user="postgres",
   dbname='Tarea_1_BD',
   password="alexinho123"
)

print(conn)
# Out:
# <connection object at 0x000001E3A0684150; dsn: 'user=postgres password=xxx dbname=Tarea_1_BD host=localhost', closed: 0>

# %% [markdown]
# ## Crear tablas
#
# Aquí inserta el código SQL que creara las tablas de la base de datos:

# %% [markdown]
# ### Tabla "Director"

# %%
# %%sql
# CREATE TABLE director(id_director INTEGER GENERATED ALWAYS AS IDENTITY,
#                     nombre VARCHAR(45) NOT NULL,
#                     edad INTEGER NOT NULL,
#                     PRIMARY KEY (id_director));
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1_BD
# Done.
# []

# %% [markdown]
# ### Tabla "Actor"

# %%
# %%sql
# CREATE TABLE actor(id_actor INTEGER GENERATED ALWAYS AS IDENTITY,
# 				  nombre VARCHAR(45) NOT NULL,
# 				  edad INTEGER NOT NULL,
# 				  primary key(id_actor));
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1_BD
# Done.
# []

# %% [markdown]
# ### Tabla "Pelicula"

# %%
# %%sql
# CREATE TABLE pelicula(id_pelicula INTEGER GENERATED ALWAYS AS IDENTITY,
# 					 id_director INTEGER NOT NULL,
# 					 nombre VARCHAR(45) NOT NULL,
# 					 genero VARCHAR(45) NOT NULL,
# 					 duracion INTEGER NOT NULL,
# 					 fecha_publicacion DATE NOT NULL,
# 					 primary key (id_pelicula),
# 					 foreign key (id_director) REFERENCES director(id_director));
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1_BD
# Done.
# []

# %% [markdown]
# ### Tabla "actor_participa_en_pelicula"

# %%
# %%sql
# CREATE TABLE actor_participa_en_pelicula(id_actor INTEGER NOT NULL,
# 										id_pelicula INTEGER NOT NULL,
# 										foreign key(id_actor) REFERENCES actor(id_actor),
# 										foreign key(id_pelicula) REFERENCES pelicula(id_pelicula));
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1_BD
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_director"

# %%
# %%sql
# CREATE TABLE premio_mejor_director(id_premio INTEGER GENERATED ALWAYS AS IDENTITY,
#                                 id_director INTEGER NOT NULL,
#                                 anio INTEGER NOT NULL,
#                                 PRIMARY KEY (id_premio),
#                                 FOREIGN KEY(id_director) REFERENCES director(id_director));
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1_BD
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_actor"

# %%
# %%sql
# CREATE TABLE premio_mejor_actor(id_premio INTEGER GENERATED ALWAYS AS IDENTITY,
# 							   id_actor INTEGER NOT NULL,
# 							   anio INTEGER NOT NULL,
# 							   primary key(id_premio),
# 							   foreign key(id_actor) REFERENCES actor(id_actor));
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1_BD
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_pelicula"

# %%
# %%sql
# CREATE TABLE premio_mejor_pelicula(id_premio INTEGER GENERATED ALWAYS AS IDENTITY,
# 								id_pelicula INTEGER NOT NULL,
#     							anio INTEGER NOT NULL,
# 								primary key(id_premio),
# 								foreign key(id_pelicula) REFERENCES pelicula(id_pelicula));
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1_BD
# Done.
# []

# %% [markdown]
# ## Código Generador de Datos
#
# Ejecute este código para cargar datos a las tablas creadas.

# %%
import random
from datetime import date
#Prefijos y sufijos para crear nombres de peliculas aleatoriamente
prefijos = ["El misterio de", "El viaje de", "Las aventuras de", "La historia de", "El secreto de", "La leyenda de", "La búsqueda de", "El regreso de", "El tesoro de", "La odisea de", "La misión de", "La conquista de", "La travesía de", "El destino de", "El despertar de", "El último viaje de", "La venganza de", "El renacimiento de", "La rebelión de", "El vuelo de", "El descubrimiento de", "La sombra de", "La redención de", "El ritual de", "La batalla de", "El hechizo de", "El pacto de", "La profecía de", "El laberinto de", "El prisionero de", "La llegada de", "El amanecer de", "La fortuna de", "El enigma de", "La invasión de", "El resurgimiento de", "La metamorfosis de", "El eclipse de", "La danza de", "La canción de", "El lamento de", "La trampa de", "La travesura de", "El tesoro escondido de", "El vuelo mágico de", "El canto de sirena de", "El bosque encantado de", "La maldición de", "La leyenda perdida de", "La tormenta de", "El camino hacia", "El viajero de", "El guardián de", "La cripta de", "El espejismo de", "El secreto oscuro de", "La resurrección de", "La danza macabra de", "La fuga de", "La estrella fugaz de", "El grito de", "El castillo de", "La travesía sin retorno de", "La estirpe de", "La llave de", "El cuento de hadas de", "El príncipe de", "La doncella de", "El arco iris de", "La fuente de", "El refugio de", "La senda de", "La búsqueda del tesoro de", "El caballero de", "La escalada de", "La maldición del vampiro de", "La travesía del océano de"]
sufijos = ["el león", "la bailarina", "el sapo", "la estrella", "el mago", "la princesa", "el guerrero", "la criatura", "el explorador", "la bruja", "la montaña", "la isla", "el dragón", "la cueva", "el lobo", "la reina", "el rey", "la espada", "el castillo", "la flor", "la selva", "el tesoro", "la nube", "el unicornio", "la sirena", "el volcán", "la neblina", "la cascada", "el árbol", "la ciudad", "el río", "la tormenta", "la luna", "el sol", "la estrella fugaz", "el camino", "la sombra", "el laberinto", "la ola", "la caverna", "el mar", "el ángel", "la espada mágica", "el destino", "el faro", "el puente", "el horizonte", "el valle", "el puente", "la muralla", "el bosque", "la gruta", "la corona", "la aldea", "la batalla", "la noche", "el amanecer", "el atardecer", "el sueño", "la pesadilla", "el héroe", "la heroína", "la aventura", "el misterio", "la magia", "la leyenda", "la profecía", "el secreto", "el desafío", "la trampa", "la mariposa", "el jardín", "la tormenta", "la montaña", "el río", "el rincón", "el guardián", "el hechizo", "la misión", "la expedición", "la caza", "el trono", "la batalla", "la aventura", "el legado", "el enigma", "la clave", "el guardián", "el viajero", "la cripta", "el laberinto", "el abismo", "el muro", "la senda", "el laberinto", "la bruma", "la travesía", "el vuelo", "la sirena", "el hechicero", "la escuela", "la academia", "la sombra", "la estrella", "el ángel", "la gárgola", "la profecía", "la puerta", "la guerra", "el pacto", "la ley", "el viaje", "la huida", "la fortuna", "la prisión", "la cárcel", "el lamento", "la sonrisa", "el susurro", "el grito", "la fuga", "el monstruo", "la bestia", "la maraña", "el sueño", "la pesadilla", "la verdad", "el mito", "el océano", "la estrella", "el fuego", "la tierra", "el cielo", "la oscuridad", "la luz", "el caos", "la esperanza", "la promesa", "la traición", "el destino", "la salvación", "la perdición", "la soledad", "la compañía", "la amistad", "el amor", "la pasión", "la venganza", "el perdón", "el renacer", "el adiós", "la bienvenida", "la despedida", "el encuentro", "la desgracia", "la fortuna", "la guerra", "la paz", "la caída", "el renacimiento", "la resistencia", "el sacrificio", "la alianza", "el viaje", "el descubrimiento", "la revelación", "la esperanza", "la batalla", "el peligro", "la aventura", "la magia", "la pesadilla", "el misterio", "la leyenda", "la guerra", "el amor", "la traición", "la redención", "la libertad", "la prisión", "la oscuridad", "la luz", "la corrupción"]
#Nombres y apellidos para crear nombres de peliculas aleatoriamente
nombres = ["Akira", "Alessandro", "Chen", "Darius", "Emiko", "Fatemeh", "Gustavo", "Hiroko", "Isa", "Jin", "Katarina", "Lakshmi", "Mikhail", "Nina", "Omar", "Pilar", "Qiu", "Rashid", "Sakura", "Tatiana", "Umar", "Valentina", "Wang", "Xavier", "Yasmin", "Zafar", "Aarav", "Beatriz", "Chidike", "Darya", "Elif", "Fadhila", "Giovanni", "Hanako", "Ilya", "Jasmin", "Khaled", "Leticia", "Mehmet", "Nadia", "Orhan", "Parvati", "Quintus", "Rania", "Salim", "Theresa", "Ursula", "Vivek", "Wilhelmina", "Xin", "Yusef", "Zoya", "Abdullah", "Bianca", "Chiyoko", "Dmitri", "Elena", "Fabiana", "Genghis", "Han", "Irina", "Javier", "Kamala", "Leonardo", "Mina", "Natalia", "Oscar", "Patricia", "Quentin", "Rosa", "Samir", "Tatjana", "Umberto", "Valeria", "Wan", "Ximena", "Yuri", "Zara"]
apellidos = ["Abadi", "Bianchi", "Cruz", "Dutta", "Etxebarria", "Ferreira", "Gao", "Hernandez", "Ivanov", "Janssen", "Kawaguchi", "Lopez", "Montenegro", "Nguyen", "Olivares", "Petrov", "Qian", "Rodriguez", "Santos", "Tan", "Ueno", "Vargas", "Wu", "Xia", "Yilmaz", "Zhang", "Almeida", "Borges", "Carvalho", "Diniz", "Esteves", "Fernandes", "Gomes", "Henriquez", "Inácio", "Joaquim", "Lima", "Mendes", "Nogueira", "Oliveira", "Pereira", "Quintana", "Ramos", "Santana", "Teixeira", "Uchoa", "Vieira", "Xavier", "Yamamoto", "Zambrano", "Alvarez", "Barros", "Correia", "Duarte", "Estevez", "Figueiredo", "Goncalves", "Hidalgo", "Iglesias", "Jimenez", "Kumar", "Lopes", "Martinez", "Nunes", "Ortega", "Pacheco", "Queiroz", "Rocha", "Sousa", "Teles", "Urbina", "Velez", "Watanabe", "Xu", "Yan", "Zapata"]
# Definir el rango de fechas
fecha_inicial = datetime(1960, 1, 1)
fecha_final = datetime(2023, 12, 31)

# Calcular la diferencia entre las fechas inicial y final
diferencia = fecha_final - fecha_inicial

# Generar una fecha aleatoria dentro del rango
fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))

# Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')

cursor = conn.cursor()

premios_info = {}
directores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(30,90)
    cursor.execute("INSERT INTO director (nombre, edad) VALUES (%s, %s) RETURNING id_director", (nombre, edad))
    id_director = cursor.fetchone()[0]
    directores_ids.append(id_director)
    
actores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(15,70) 
    cursor.execute("INSERT INTO actor (nombre, edad) VALUES (%s, %s) RETURNING id_actor", (nombre, edad))
    id_actor = cursor.fetchone()[0]
    actores_ids.append(id_actor)

peliculas_ids = []
for _ in range(300):
    director_pelicula = random.choice(directores_ids)
    nombre = random.choice(prefijos) + " " + random.choice(sufijos)
    genero = random.choice(["Acción", "Aventura", "Animación", "Comedia", "Documental", "Drama", "Fantasía", "Terror", "Ciencia ficción", "Musical", "Misterio", "Romance", "Suspense", "Western"])
    duracion = random.randint(70,150)
    fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))
    # Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
    fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')
    cursor.execute("INSERT INTO pelicula (id_director, nombre, genero, duracion, fecha_publicacion) VALUES (%s,%s,%s,%s,%s) RETURNING id_pelicula",(director_pelicula,nombre,genero,duracion,fecha_sql))
    id_pelicula = cursor.fetchone()[0]
    peliculas_ids.append(id_pelicula)
    if id_pelicula not in premios_info:
        premios_info[id_pelicula] = {}
        premios_info[id_pelicula]["año"] = fecha_aleatoria.year
        premios_info[id_pelicula]["director"] = director_pelicula
        premios_info[id_pelicula]["genero"] = genero
        premios_info[id_pelicula]["cast"] = []
        premios_info[id_pelicula]["mejor pelicula"] = "no"
    
lista_pelicula_actor = []
peliculas_actores = {}
for _ in range(500):
    peliculaID = random.choice(peliculas_ids)
    actorID = random.choice(actores_ids)
    if not (peliculaID, actorID) in lista_pelicula_actor:
        cursor.execute("INSERT INTO actor_participa_en_pelicula (id_pelicula, id_actor) VALUES (%s,%s)",(peliculaID,actorID))
        lista_pelicula_actor.append((peliculaID,actorID))
    else:
        continue


for pelicula, actor in lista_pelicula_actor:
    if pelicula in premios_info:
        premios_info[pelicula]["cast"].append(actor)

print(premios_info)
for _ in range(100):
    pelicula_al_azar = random.randint(1,300)
    tipo_de_premio = ["mejor pelicula", "mejor actor", "mejor director"]
    eleccion_premio = random.choice(tipo_de_premio)
    if eleccion_premio == "mejor director":
        if premios_info[pelicula_al_azar]["director"] != "elegido":
            director = premios_info[pelicula_al_azar]["director"]
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_director (id_director, anio) VALUES (%s,%s)",(director, año))
            premios_info[pelicula_al_azar]["director"] = "elegido"
        else:
            continue
    elif eleccion_premio == "mejor actor":
        if premios_info[pelicula_al_azar]["cast"] != []:
            actor = random.choice(premios_info[pelicula_al_azar]["cast"])
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_actor (id_actor, anio) VALUES (%s,%s)",(actor, año))
            premios_info[pelicula_al_azar]["cast"].remove(actor)
        else:
            continue
    elif eleccion_premio == "mejor pelicula":
        if premios_info[pelicula_al_azar]["mejor pelicula"] != "si":
            pelicula = pelicula_al_azar
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_pelicula (id_pelicula, anio) VALUES (%s,%s)",(pelicula, año))
            premios_info[pelicula_al_azar]["mejor pelicula"] = "si"
        else:
            continue

conn.commit()
cursor.close()
conn.close()
# Out:
# {1: {'año': 1980, 'director': 102, 'genero': 'Ciencia ficción', 'cast': [59, 29, 23, 30], 'mejor pelicula': 'no'}, 2: {'año': 1991, 'director': 108, 'genero': 'Comedia', 'cast': [86], 'mejor pelicula': 'no'}, 3: {'año': 1967, 'director': 171, 'genero': 'Ciencia ficción', 'cast': [], 'mejor pelicula': 'no'}, 4: {'año': 2021, 'director': 50, 'genero': 'Suspense', 'cast': [11, 177, 182, 165], 'mejor pelicula': 'no'}, 5: {'año': 1985, 'director': 150, 'genero': 'Animación', 'cast': [62, 33, 166], 'mejor pelicula': 'no'}, 6: {'año': 2006, 'director': 80, 'genero': 'Western', 'cast': [3], 'mejor pelicula': 'no'}, 7: {'año': 2006, 'director': 77, 'genero': 'Misterio', 'cast': [], 'mejor pelicula': 'no'}, 8: {'año': 1979, 'director': 108, 'genero': 'Aventura', 'cast': [90], 'mejor pelicula': 'no'}, 9: {'año': 1960, 'director': 63, 'genero': 'Fantasía', 'cast': [34], 'mejor pelicula': 'no'}, 10: {'año': 2011, 'director': 39, 'genero': 'Aventura', 'cast': [], 'mejor pelicula': 'no'}, 11: {'año': 1978, 'director': 122, 'genero': 'Terror', 'cast': [170], 'mejor pelicula': 'no'}, 12: {'año': 2012, 'director': 125, 'genero': 'Ciencia ficción', 'cast': [69], 'mejor pelicula': 'no'}, 13: {'año': 2007, 'director': 16, 'genero': 'Aventura', 'cast': [193], 'mejor pelicula': 'no'}, 14: {'año': 1963, 'director': 119, 'genero': 'Western', 'cast': [33, 66, 163], 'mejor pelicula': 'no'}, 15: {'año': 2021, 'director': 158, 'genero': 'Ciencia ficción', 'cast': [118], 'mejor pelicula': 'no'}, 16: {'año': 1987, 'director': 170, 'genero': 'Ciencia ficción', 'cast': [], 'mejor pelicula': 'no'}, 17: {'año': 1994, 'director': 48, 'genero': 'Romance', 'cast': [], 'mejor pelicula': 'no'}, 18: {'año': 1981, 'director': 176, 'genero': 'Acción', 'cast': [106, 199], 'mejor pelicula': 'no'}, 19: {'año': 1964, 'director': 93, 'genero': 'Drama', 'cast': [105, 116, 147], 'mejor pelicula': 'no'}, 20: {'año': 1977, 'director': 99, 'genero': 'Fantasía', 'cast': [154, 53, 11, 198], 'mejor pelicula': 'no'}, 21: {'año': 1962, 'director': 114, 'genero': 'Suspense', 'cast': [79], 'mejor pelicula': 'no'}, 22: {'año': 1968, 'director': 111, 'genero': 'Comedia', 'cast': [124, 130, 3, 193], 'mejor pelicula': 'no'}, 23: {'año': 1974, 'director': 200, 'genero': 'Suspense', 'cast': [38, 23, 37], 'mejor pelicula': 'no'}, 24: {'año': 2020, 'director': 56, 'genero': 'Suspense', 'cast': [], 'mejor pelicula': 'no'}, 25: {'año': 1996, 'director': 189, 'genero': 'Aventura', 'cast': [146, 152], 'mejor pelicula': 'no'}, 26: {'año': 1982, 'director': 117, 'genero': 'Musical', 'cast': [55, 120, 112], 'mejor pelicula': 'no'}, 27: {'año': 1967, 'director': 144, 'genero': 'Animación', 'cast': [193], 'mejor pelicula': 'no'}, 28: {'año': 1969, 'director': 155, 'genero': 'Ciencia ficción', 'cast': [133, 61], 'mejor pelicula': 'no'}, 29: {'año': 2002, 'director': 165, 'genero': 'Western', 'cast': [113], 'mejor pelicula': 'no'}, 30: {'año': 1996, 'director': 65, 'genero': 'Fantasía', 'cast': [126], 'mejor pelicula': 'no'}, 31: {'año': 1995, 'director': 94, 'genero': 'Fantasía', 'cast': [142], 'mejor pelicula': 'no'}, 32: {'año': 1995, 'director': 169, 'genero': 'Suspense', 'cast': [65, 120], 'mejor pelicula': 'no'}, 33: {'año': 2021, 'director': 17, 'genero': 'Suspense', 'cast': [15], 'mejor pelicula': 'no'}, 34: {'año': 2020, 'director': 173, 'genero': 'Documental', 'cast': [], 'mejor pelicula': 'no'}, 35: {'año': 1966, 'director': 113, 'genero': 'Animación', 'cast': [197, 168], 'mejor pelicula': 'no'}, 36: {'año': 1993, 'director': 87, 'genero': 'Documental', 'cast': [], 'mejor pelicula': 'no'}, 37: {'año': 1996, 'director': 169, 'genero': 'Romance', 'cast': [37, 18, 149], 'mejor pelicula': 'no'}, 38: {'año': 1968, 'director': 46, 'genero': 'Aventura', 'cast': [105], 'mejor pelicula': 'no'}, 39: {'año': 2018, 'director': 71, 'genero': 'Drama', 'cast': [], 'mejor pelicula': 'no'}, 40: {'año': 1984, 'director': 134, 'genero': 'Documental', 'cast': [134, 121], 'mejor pelicula': 'no'}, 41: {'año': 1971, ...

# %% [markdown]
# ## Consultas
#
# Escriba aquí las consultas pedidas. Recuerde agregar una descripción _breve_ de cómo funciona la solución. **Escriba las consultas de forma ordenada.**
#
# **NOTA:** Cuando en una consulta diga "X cosa" significa que ustedes deben de elegir ese X por lo que para cualquier otro X debe de funcionar de igual forma.

# %% [markdown]
# ### Consulta 1
# **Nombre de todas las películas publicadas desde el año pasado.**
#
#
# **Ejemplo:**
# |Nombre|
# |------|
# |Dune 2|
# |...|
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1_BD
# (psycopg2.ProgrammingError) can't execute an empty query
# [SQL: /* Reemplace estas queries por las que resuelven las consultas pedidas. */]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Consulta 2
# **Nombre y fecha de publicación de todas las películas del género drama que hayan sido publicadas en el año 2023.**
#
#
# **Ejemplo:**
#
# |Nombre     |Fecha de publicación|
# |-----------|--------------------|
# |Oppenheimer|21-7-2023          |
# |...        |...                 |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1_BD
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta 3
# **Nombres de todos los actores que participaron en una película de género comedia.**
#
#
# **Ejemplo:**
# |Nombre       |
# |-------------|
# |Margot Robbie|
# |...          |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1_BD
# (psycopg2.ProgrammingError) can't execute an empty query
# [SQL: /* Reemplace estas queries por las que resuelven las consultas pedidas. */]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Consulta 4
# **Nombre y cantidad de premios ganados por cada género, ordenados de mayor a menor según la cantidad de premios.**
#
#
# **Ejemplo:**
# |Género  |Cantidad de premios|
# |--------|-------------------|
# |Drama   |99                 |
# |Fantasía|29                 |
# |...     |...                |
#
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 5
# **Mostrar peliculas que tengan 2 o mas actores/actrices ordenadas de mayor a menor segun la cantidad de actores/actrices.**
#
#
# **Ejemplo:**
# |Nombre     |Cantidad de actores|
# |-----------|-------------------|
# |Oppenheimer|7                  |
# |Poor Things|4                  |
# |...        |...                |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 6
# **Nombre de la película con la mayor brecha de edad entre el actor más joven y el actor más viejo que participen en ella, y las edades de dichos actores.** (Si hay empate, mostrar solamente uno).
#
#
# **Ejemplo:**
# |Nombre|Edad del actor más joven|Edad del actor más viejo|
# |------|------------------------|------------------------|
# |Barbie|16                      |92                      |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 7
# **Año de cada premio ganado por la película de mayor duración.** (Si hay empate, elegir solamente uno).
#
#
# **Ejemplo:**
# |Año |
# |----|
# |2024|
# |... |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# SELECT anio AS "Año"
# from premio_mejor_pelicula
# inner join pelicula
# on premio_mejor_pelicula.id_pelicula = pelicula.id_pelicula
# where duracion = (select max(duracion)
# 				 from pelicula)
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1_BD
# 1 rows affected.
# [(2020,)]

# %% [markdown]
# ### Consulta 8
# **Nombre de todos los actores que han trabajado con más de un director, la cantidad de directores con las que han trabajado y el nombre de una de las películas.**
#
#
# **Ejemplo:**
# |Nombre del actor|Cantidad de directores|Nombre de una película|
# |----------------|----------------------|----------------------|
# |Cillian Murphy  |29                    |Oppenheimer           |
# |...             |...                   |...                   |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# SELECT actor.nombre AS "Nombre del actor", count(DISTINCT director.id_director) AS "Cantidad de directores",
# MIN(pelicula.nombre) AS "Nombre de una película"
#
# from actor
#
# inner join actor_participa_en_pelicula on actor.id_actor = actor_participa_en_pelicula.id_actor
# inner join pelicula on actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
# inner join director on pelicula.id_director = director.id_director
#
# group by actor.nombre
#
# HAVING count(DISTINCT director.id_director) > 1
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1_BD
# 137 rows affected.
# [('Aarav Vieira', 5, 'El caballero de la cripta'),
#  ('Abdullah Alvarez', 2, 'La fortuna de el guardián'),
#  ('Abdullah Nogueira', 3, 'El despertar de el faro'),
#  ('Abdullah Zapata', 5, 'El guardián de la revelación'),
#  ('Akira Rodriguez', 3, 'La leyenda perdida de la perdición'),
#  ('Beatriz Nogueira', 4, 'El descubrimiento de el grito'),
#  ('Beatriz Santana', 2, 'La fuente de el ángel'),
#  ('Beatriz Santos', 3, 'El grito de la flor'),
#  ('Beatriz Wu', 2, 'La canción de la flor'),
#  ('Bianca Qian', 4, 'El camino hacia la estrella'),
#  ('Chen Bianchi', 3, 'El camino hacia el destino'),
#  ('Chidike Iglesias', 5, 'El eclipse de la pesadilla'),
#  ('Chidike Pereira', 3, 'El ritual de el viaje'),
#  ('Chidike Ramos', 4, 'El cuento de hadas de el renacer'),
#  ('Chiyoko Henriquez', 3, 'El bosque encantado de el mito'),
#  ('Darius Correia', 6, 'El despertar de la montaña'),
#  ('Darius Duarte', 2, 'El lamento de el mar'),
#  ('Darius Zhang', 2, 'El guardián de el guardián'),
#  ('Darya Rodriguez', 4, 'El caballero de la paz'),
#  ('Dmitri Cruz', 4, 'El hechizo de la guerra'),
#  ('Dmitri Yilmaz', 5, 'El misterio de la montaña'),
#  ('Elif Teles', 3, 'El despertar de el laberinto'),
#  ('Genghis Sousa', 4, 'El camino hacia la estrella'),
#  ('Giovanni Xavier', 3, 'El despertar de el árbol'),
#  ('Gustavo Gao', 5, 'El caballero de la ola'),
#  ('Gustavo Joaquim', 2, 'La búsqueda del tesoro de el hechizo'),
#  ('Gustavo Santana', 6, 'El destino de la leyenda'),
#  ('Gustavo Vargas', 2, 'El despertar de la misión'),
#  ('Han Petrov', 4, 'El camino hacia el perdón'),
#  ('Hanako Rocha', 3, 'El resurgimiento de el amor'),
#  ('Hanako Teles', 2, 'La estrella fugaz de la profecía'),
#  ('Hanako Yamamoto', 2, 'La estrella fugaz de la misión'),
#  ('Hiroko Ferreira', 3, 'El cuento de hadas de el ángel'),
#  ('Ilya Bianchi', 3, 'El descubrimiento de el grito'),
#  ('Ilya Correia', 6, 'El descubrimiento de el puente'),
#  ('Ilya Etxebarria', 4, 'El camino hacia el destino'),
#  ('Ilya Yamamoto', 2, 'El resurgimiento de el amor'),
#  ('Irina Etxebarria', 3, 'El canto de sirena de el río'),
#  ('Irina Gao', 3, 'El guardián de el encuentro'),
#  ('Irina Kumar', 2, 'El grito de la flor'),
#  ('Irina Olivares', 2, 'El castillo de la espada'),
#  ('Isa Oliveira', 3, 'El prisionero de la bestia'),
#  ('Isa Tan', 4, 'El despertar de la montaña'),
#  ('Jasmin Carvalho', 3, 'El refugio de la batalla'),
#  ('Jasmin Esteves', 2, 'El vuelo de la espada mágica'),
#  ('Jasmin Estevez', 2, 'El secreto de la despedida'),
#  ('Jasmin Lopez', 2, 'La leyenda perdida de la estrella'),
#  ('Jasmin Teles', 2, 'El hechizo de la guerra'),
#  ('Javier Xia', 4, 'El caballero de la paz'),
#  ('Kamala Rocha', 2, 'El grito de la flor'),
#  ('Kamala Wu', 6, 'El arco iris de la sirena'),
#  ('Kamala Xu', 2, 'El tesoro de la sombra'),
#  ('Katarina Montenegro', 2, 'La fortuna de el susurro'),
#  ('Khaled Nogueira', 3, 'El caballero de la cripta'),
#  ('Lakshmi Gomes', 4, 'El canto de sirena de el sueño'),
#  ('Lakshmi Nogueira', 3, 'El prisionero de el bosque'),
#  ('Lakshmi Teles', 2, 'La conquista de la caverna'),
#  ('Leonardo Iglesias', 3, 'El lamento de el mar'),
#  ('Leonardo Inácio', 2, 'El secreto de la despedida'),
#  ('Leonardo Jimenez', 7, 'El arco iris de la sirena'),
#  ('Leticia Montenegro', 3, 'El eclipse de la batalla'),
#  ('Mehmet Almeida', 2, 'El destino de la leyenda'),
#  ('Mehmet Martinez', 3, 'El amanecer de el tesoro'),
#  ('Mikhail Nogueira', 4, 'El descubrimiento de el puente'),
#  ('Mikhail Velez', 2, 'El tesoro escondido de el rincón'),
#  ('Mikhail Zapata', 3, 'El arco iris de el laberinto'),
#  ('Mina Diniz', 2, 'El caballero de la cripta'),
#  ('Mina Gao', 2, 'El tesoro escondido de el encuentro'),
#  ('Mina Olivares', 7, 'El cuento de hadas de la flor'),
#  ('Nadia Carvalho', 2, 'El despertar de la guerra'),
#  ('Nadia Rodriguez', 2, 'El canto de sirena de la estrella fugaz'),
#  ('Omar Vieira', 4, 'El laberinto de la estrella'),
#  ('Orhan Figueiredo', 2, 'La búsqueda de la prisión'),
#  ('Orhan Iglesias', 5, 'El camino hacia el destino'),
#  ('Oscar Rodriguez', 4, 'El bosque encantado de la montaña'),
#  ('Parvati Ivanov', 2, 'La maldición del vampiro de el desafío'),
#  ('Parvati Martinez', 4, 'El misterio de la estrella'),
#  ('Parvati Sousa', 2, 'El despertar de la guerra'),
#  ('Parvati Vieira', 2, 'El caballero de la paz'),
#  ('Patricia Lima', 2, 'El tesoro de la sombra'),
#  ('Pilar Lima', 5, 'El camino hacia el misterio'),
#  ('Pilar Oliveira', 6, 'El cuento de hadas de el renacer'),
#  ('Qiu Joaquim', 2, 'El guardián de el encuentro'),
#  ('Qiu Watanabe', 3, 'El castillo de la espada'),
#  ('Quentin Almeida', 2, 'El caballero de la cripta'),
#  ('Quentin Iglesias', 2, 'El camino hacia la estrella'),
#  ('Quentin Nunes', 2, 'El despertar de el faro'),
#  ('Quentin Santana', 2, 'La leyenda de el peligro'),
#  ('Quentin Zambrano', 3, 'El viaje de la traición'),
#  ('Quintus Rocha', 3, 'El tesoro escondido de el sueño'),
#  ('Rania Bianchi', 2, 'La batalla de la guerra'),
#  ('Rania Goncalves', 5, 'El cuento de hadas de la flor'),
#  ('Rashid Gomes', 3, 'El secreto de el faro'),
#  ('Rashid Lima', 3, 'El ritual de la verdad'),
#  ('Rashid Uchoa', 5, 'La canción de el monstruo'),
#  ('Rashid Xavier', 2, 'El enigma de la pasión'),
#  ('Rosa Oliveira', 4, 'El descubrimiento de el renacimiento'),
#  ('Rosa Qian', 2, 'La búsqueda del tesoro de el hechizo'),
#  ('Rosa Queiroz', 2, 'La fuente de la libertad'),
#  ('Rosa Zapata', 4, 'El descubrimiento de el grito'),
#  ('Sakura Hernandez', 3, 'El prisionero de la bestia'),
#  ('Salim Janssen', 7, 'El amanecer de el tesoro'),
#  ('Salim Uchoa', 8, 'El hechizo de la guerra'),
#  ('Salim Xu', 3, 'El misterio de la estrella'),
#  ('Tatiana Bianchi', 3, 'El grito de la pesadilla'),
#  ('Tatiana Petrov', 4, 'La canción de la pasión'),
#  ('Tatjana Pereira', 2, 'El prisionero de el bosque'),
#  ('Tatjana Rodriguez', 2, 'El ritual de la soledad'),
#  ('Theresa Diniz', 3, 'El canto de sirena de el sueño'),
#  ('Theresa Montenegro', 4, 'El cuento de hadas de la flor'),
#  ('Theresa Uchoa', 7, 'El bosque encantado de el mito'),
#  ('Umar Janssen', 2, 'El despertar de el laberinto'),
#  ('Ursula Ivanov', 3, 'La búsqueda del tesoro de la leyenda'),
#  ('Ursula Jimenez', 3, 'El lamento de la bienvenida'),
#  ('Ursula Sousa', 4, 'El canto de sirena de el sueño'),
#  ('Valentina Oliveira', 3, 'El destino de la sombra'),
#  ('Vivek Petrov', 5, 'El tesoro de la sombra'),
#  ('Wan Hidalgo', 3, 'El enigma de la pasión'),
#  ('Wilhelmina Barros', 3, 'El canto de sirena de la estrella fugaz'),
#  ('Wilhelmina Teles', 5, 'El resurgimiento de el unicornio'),
#  ('Xavier Gao', 3, 'El grito de la flor'),
#  ('Xavier Queiroz', 3, 'La llegada de la sonrisa'),
#  ('Xin Gomes', 3, 'El laberinto de el desafío'),
#  ('Xin Rocha', 2, 'El cuento de hadas de la gárgola'),
#  ('Xin Teles', 5, 'La fortuna de el renacimiento'),
#  ('Yasmin Carvalho', 2, 'El vuelo de el susurro'),
#  ('Yasmin Ferreira', 3, 'El castillo de la espada'),
#  ('Yasmin Olivares', 2, 'La llave de la estrella'),
#  ('Yasmin Watanabe', 3, 'El bosque encantado de el mito'),
#  ('Yuri Teixeira', 3, 'La leyenda perdida de la estrella'),
#  ('Yusef Henriquez', 4, 'El guardián de la revelación'),
#  ('Zafar Pereira', 3, 'El amanecer de el sacrificio'),
#  ('Zafar Zambrano', 5, 'El castillo de la espada'),
#  ('Zara Borges', 3, 'El amanecer de el tesoro'),
#  ('Zara Yan', 4, 'La estrella fugaz de la bestia'),
#  ('Zoya Joaquim', 4, 'El vuelo de el jardín'),
#  ('Zoya Urbina', 2, 'El camino hacia la cascada')]

# %% [markdown]
# ### Consulta 9
#
# **Nombre de todos los actores que han participado sólo en películas dirigidas por el director con id\_director 1.**
#
#
# **Ejemplo:**
# |Nombre      |
# |------------|
# |Ryan Gosling|
# |...         |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# SELECT actor.nombre AS "Nombre"
# from actor
# inner join actor_participa_en_pelicula on actor.id_actor = actor_participa_en_pelicula.id_actor
# inner join pelicula on actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
# where pelicula.id_director = '1'
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea_1_BD
# 3 rows affected.
# [('Quentin Santana',), ('Jasmin Carvalho',), ('Wilhelmina Teles',)]

# %% [markdown]
# ### Consulta BONUS
#
# **Nombre de todos los actores que nunca han ganado un premio, todas las películas en las que han participado y el nombre, número total de películas y número total de premios de los directores de cada película.**
#
#
# **Ejemplo:**
# |Nombre del actor|Nombre de la película|Nombre del director|Número de películas del director|Número de premios del director|
# |----------------|---------------------|-------------------|--------------------------------|-----------------------|
# |Mark Ruffalo    |Poor Things          |Yorgos Lanthimos   |4                               |0                      |
# |Saoirse Ronan   |Lady Bird            |Greta Gerwig       |20                              |1                      |
# |Saoirse Ronan   |Little Women         |Greta Gerwig       |20                              |1                      |
# |...             |...                  |...                |...                             |...                    |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# SELECT *
#
# from actor
#
# inner join actor_participa_en_pelicula on actor.id_actor = actor_participa_en_pelicula.id_actor
# inner join pelicula on actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
# inner join director on pelicula.id_director = director.id_director
#
# order by actor.nombre
# Out:
# 498 rows affected.
# [(42, 'Aarav Barros', 20, 42, 37, 37, 20, 'La búsqueda del tesoro de la profecía', 'Animación', 114, datetime.date(1989, 6, 1), 20, 'Valeria Carvalho', 59),
#  (42, 'Aarav Barros', 20, 42, 281, 281, 174, 'La odisea de la magia', 'Terror', 131, datetime.date(2003, 8, 20), 174, 'Vivek Yilmaz', 49),
#  (137, 'Aarav Hidalgo', 51, 137, 140, 140, 102, 'La historia de el mago', 'Romance', 95, datetime.date(2019, 10, 12), 102, 'Wan Watanabe', 33),
#  (63, 'Aarav Lopes', 40, 63, 285, 285, 14, 'El hechizo de la mariposa', 'Suspense', 113, datetime.date(1997, 1, 12), 14, 'Pilar Pereira', 36),
#  (63, 'Aarav Lopes', 40, 63, 204, 204, 197, 'El tesoro escondido de el valle', 'Ciencia ficción', 107, datetime.date(1974, 9, 27), 197, 'Yuri Wu', 73),
#  (63, 'Aarav Lopes', 40, 63, 175, 175, 19, 'El pacto de la muralla', 'Terror', 121, datetime.date(1969, 7, 18), 19, 'Tatiana Estevez', 81),
#  (193, 'Aarav Yamamoto', 33, 193, 244, 244, 74, 'El pacto de la verdad', 'Acción', 129, datetime.date(1993, 9, 18), 74, 'Aarav Nguyen', 33),
#  (193, 'Aarav Yamamoto', 33, 193, 298, 298, 147, 'La travesía sin retorno de el perdón', 'Terror', 144, datetime.date(1974, 1, 19), 147, 'Umar Pereira', 66),
#  (193, 'Aarav Yamamoto', 33, 193, 2, 2, 91, 'La invasión de el árbol', 'Aventura', 71, datetime.date(1980, 8, 28), 91, 'Khaled Oliveira', 67),
#  (193, 'Aarav Yamamoto', 33, 193, 209, 209, 100, 'La escalada de la aldea', 'Drama', 77, datetime.date(1973, 8, 11), 100, 'Abdullah Ramos', 72),
#  (47, 'Aarav Yan', 58, 47, 14, 14, 199, 'La doncella de el laberinto', 'Acción', 143, datetime.date(1964, 1, 23), 199, 'Zara Teixeira', 88),
#  (47, 'Aarav Yan', 58, 47, 112, 112, 63, 'La doncella de el ángel', 'Misterio', 82, datetime.date(1984, 4, 23), 63, 'Samir Yan', 34),
#  (47, 'Aarav Yan', 58, 47, 124, 124, 93, 'El secreto oscuro de la estrella fugaz', 'Romance', 95, datetime.date(1983, 8, 1), 93, 'Qiu Lima', 76),
#  (47, 'Aarav Yan', 58, 47, 285, 285, 14, 'El hechizo de la mariposa', 'Suspense', 113, datetime.date(1997, 1, 12), 14, 'Pilar Pereira', 36),
#  (47, 'Aarav Yan', 58, 47, 98, 98, 176, 'El vuelo mágico de la desgracia', 'Suspense', 131, datetime.date(1988, 4, 6), 176, 'Wan Lopez', 86),
#  (47, 'Aarav Yan', 58, 47, 227, 227, 111, 'La travesura de la aventura', 'Drama', 101, datetime.date(1981, 4, 2), 111, 'Sakura Qian', 88),
#  (90, 'Abdullah Esteves', 37, 90, 139, 139, 65, 'La tormenta de la bruja', 'Romance', 137, datetime.date(1965, 11, 4), 65, 'Umar Qian', 90),
#  (90, 'Abdullah Esteves', 37, 90, 31, 31, 10, 'La batalla de la traición', 'Musical', 78, datetime.date(1979, 3, 18), 10, 'Valeria Santos', 66),
#  (90, 'Abdullah Esteves', 37, 90, 25, 25, 78, 'La rebelión de el castillo', 'Ciencia ficción', 136, datetime.date(1994, 5, 8), 78, 'Wang Abadi', 66),
#  (90, 'Abdullah Esteves', 37, 90, 61, 61, 94, 'La búsqueda de el enigma', 'Musical', 84, datetime.date(2013, 12, 30), 94, 'Gustavo Santana', 54),
#  (64, 'Abdullah Estevez', 17, 64, 264, 264, 112, 'La rebelión de el faro', 'Ciencia ficción', 130, datetime.date(1970, 4, 11), 112, 'Alessandro Lopez', 73),
#  (64, 'Abdullah Estevez', 17, 64, 232, 232, 151, 'La fortuna de el unicornio', 'Comedia', 142, datetime.date(1988, 5, 13), 151, 'Valeria Borges', 32),
#  (64, 'Abdullah Estevez', 17, 64, 101, 101, 76, 'El cuento de hadas de el tesoro', 'Ciencia ficción', 89, datetime.date(2003, 8, 14), 76, 'Jasmin Quintana', 71),
#  (8, 'Abdullah Fernandes', 37, 8, 164, 164, 82, 'El viajero de la fuga', 'Animación', 101, datetime.date(1964, 2, 1), 82, 'Vivek Ferreira', 72),
#  (41, 'Abdullah Ferreira', 57, 41, 76, 76, 160, 'La maldición del vampiro de el renacer', 'Documental', 128, datetime.date(1994, 10, 15), 160, 'Lakshmi Kawaguchi', 84),
#  (41, 'Abdullah Ferreira', 57, 41, 118, 118, 3, 'La búsqueda del tesoro de el unicornio', 'Aventura', 148, datetime.date(1980, 8, 15), 3, 'Leticia Quintana', 33),
#  (41, 'Abdullah Ferreira', 57, 41, 193, 193, 160, 'La conquista de la resistencia', 'Acción', 82, datetime.date(2018, 3, 8), 160, 'Lakshmi Kawaguchi', 84),
#  (41, 'Abdullah Ferreira', 57, 41, 51, 51, 9, 'La resurrección de el hechicero', 'Aventura', 83, datetime.date(2008, 3, 19), 9, 'Fadhila Fernandes', 31),
#  (127, 'Abdullah Janssen', 52, 127, 212, 212, 22, 'La doncella de el viaje', 'Musical', 107, datetime.date(1990, 2, 2), 22, 'Giovanni Santana', 59),
#  (127, 'Abdullah Janssen', 52, 127, 30, 30, 74, 'El misterio de el destino', 'Suspense', 88, datetime.date(2000, 6, 20), 74, 'Aarav Nguyen', 33),
#  (68, 'Abdullah Jimenez', 56, 68, 203, 203, 32, 'La senda de el cielo', 'Misterio', 114, datetime.date(1997, 6, 16), 32, 'Zoya Bianchi', 33),
#  (68, 'Abdullah Jimenez', 56, 68, 118, 118, 3, 'La búsqueda del tesoro de el unicornio', 'Aventura', 148, datetime.date(1980, 8, 15), 3, 'Leticia Quintana', 33),
#  (68, 'Abdullah Jimenez', 56, 68, 92, 92, 31, 'El secreto de la bienvenida', 'Documental', 118, datetime.date(2000, 8, 15), 31, 'Mina Zambrano', 64),
#  (84, 'Abdullah Qian', 55, 84, 210, 210, 67, 'El misterio de la pesadilla', 'Suspense', 116, datetime.date(1996, 10, 31), 67, 'Khaled Dutta', 77),
#  (84, 'Abdullah Qian', 55, 84, 77, 77, 84, 'El cuento de hadas de la aldea', 'Ciencia ficción', 129, datetime.date(1995, 11, 25), 84, 'Parvati Vieira', 73),
#  (52, 'Abdullah Teles', 57, 52, 39, 39, 114, 'El príncipe de el destino', 'Musical', 120, datetime.date(2022, 4, 1), 114, 'Valentina Mendes', 44),
#  (52, 'Abdullah Teles', 57, 52, 201, 201, 145, 'El cuento de hadas de la estrella', 'Acción', 109, datetime.date(2015, 2, 7), 145, 'Tatjana Rodriguez', 60),
#  (52, 'Abdullah Teles', 57, 52, 73, 73, 16, 'El hechizo de la caza', 'Terror', 143, datetime.date(2010, 7, 30), 16, 'Hiroko Xu', 87),
#  (52, 'Abdullah Teles', 57, 52, 107, 107, 56, 'El vuelo de el peligro', 'Acción', 137, datetime.date(2003, 10, 20), 56, 'Akira Rocha', 34),
#  (73, 'Akira Bianchi', 50, 73, 225, 225, 118, 'La metamorfosis de la academia', 'Western', 85, datetime.date(1993, 1, 3), 118, 'Chidike Ramos', 86),
#  (73, 'Akira Bianchi', 50, 73, 74, 74, 83, 'La búsqueda del tesoro de el descubrimiento', 'Misterio', 138, datetime.date(2004, 2, 7), 83, 'Vivek Zapata', 68),
#  (73, 'Akira Bianchi', 50, 73, 234, 234, 24, 'La leyenda de la oscuridad', 'Musical', 94, datetime.date(2018, 6, 10), 24, 'Aarav Queiroz', 51),
#  (73, 'Akira Bianchi', 50, 73, 222, 222, 54, 'El vuelo mágico de la montaña', 'Aventura', 80, datetime.date(1972, 4, 23), 54, 'Chiyoko Teixeira', 34),
#  (73, 'Akira Bianchi', 50, 73, 202, 202, 72, 'La escalada de la pesadilla', 'Animación', 70, datetime.date(2003, 2, 11), 72, 'Theresa Qian', 73),
#  (99, 'Akira Olivares', 67, 99, 44, 44, 191, 'La senda de la ley', 'Western', 87, datetime.date(1975, 7, 26), 191, 'Beatriz Bianchi', 73),
#  (99, 'Akira Olivares', 67, 99, 299, 299, 167, 'El lamento de el héroe', 'Drama', 100, datetime.date(2018, 12, 21), 167, 'Mina Fernandes', 35),
#  (99, 'Akira Olivares', 67, 99, 23, 23, 187, 'La odisea de la sonrisa', 'Aventura', 122, datetime.date(2005, 8, 27), 187, 'Khaled Vargas', 32),
#  (99, 'Akira Olivares', 67, 99, 289, 289, 24, 'El lamento de la ola', 'Western', 86, datetime.date(1984, 10, 4), 24, 'Aarav Queiroz', 51),
#  (99, 'Akira Olivares', 67, 99, 65, 65, 127, 'La misión de el sol', 'Aventura', 117, datetime.date(1973, 7, 12), 127, 'Zafar Ramos', 80),
#  (128, 'Akira Xu', 29, 128, 32, 32, 84, 'El tesoro de la caverna', 'Comedia', 130, datetime.date(1980, 4, 10), 84, 'Parvati Vieira', 73),
#  (70, 'Akira Xu', 46, 70, 107, 107, 56, 'El vuelo de el peligro', 'Acción', 137, datetime.date(2003, 10, 20), 56, 'Akira Rocha', 34),
#  (128, 'Akira Xu', 29, 128, 162, 162, 157, 'El regreso de el jardín', 'Documental', 103, datetime.date(2020, 4, 10), 157, 'Leticia Correia', 34),
#  (128, 'Akira Xu', 29, 128, 257, 257, 79, 'La metamorfosis de el abismo', 'Suspense', 137, datetime.date(2004, 3, 31), 79, 'Omar Barros', 58),
#  (29, 'Alessandro Almeida', 35, 29, 152, 152, 185, 'El regreso de el héroe', 'Suspense', 94, datetime.date(1970, 12, 18), 185, 'Wan Correia', 32),
#  (29, 'Alessandro Almeida', 35, 29, 92, 92, 31, 'El secreto de la bienvenida', 'Documental', 118, datetime.date(2000, 8, 15), 31, 'Mina Zambrano', 64),
#  (29, 'Alessandro Almeida', 35, 29, 236, 236, 71, 'El príncipe de la amistad', 'Musical', 123, datetime.date(1983, 10, 15), 71, 'Leticia Martinez', 53),
#  (49, 'Beatriz Jimenez', 29, 49, 132, 132, 21, 'El tesoro de la estrella', 'Ciencia ficción', 132, datetime.date(1961, 2, 8), 21, 'Emiko Yan', 90),
#  (49, 'Beatriz Jimenez', 29, 49, 60, 60, 52, 'El camino hacia la noche', 'Fantasía', 110, datetime.date(1992, 7, 13), 52, 'Katarina Qian', 41),
#  (49, 'Beatriz Jimenez', 29, 49, 105, 105, 72, 'El cuento de hadas de la cripta', 'Comedia', 99, datetime.date(1979, 9, 29), 72, 'Theresa Qian', 73),
#  (49, 'Beatriz Jimenez', 29, 49, 75, 75, 159, 'La estrella fugaz de el amor', 'Acción', 130, datetime.date(1987, 9, 23), 159, 'Oscar Quintana', 42),
#  (67, 'Beatriz Ortega', 62, 67, 28, 28, 93, 'La estirpe de el perdón', 'Aventura', 112, datetime.date(1979, 9, 23), 93, 'Qiu Lima', 76),
#  (67, 'Beatriz Ortega', 62, 67, 182, 182, 189, 'La doncella de la montaña', 'Comedia', 137, datetime.date(1961, 7, 25), 189, 'Khaled Gomes', 31),
#  (67, 'Beatriz Ortega', 62, 67, 175, 175, 19, 'El pacto de la muralla', 'Terror', 121, datetime.date(1969, 7, 18), 19, 'Tatiana Estevez', 81),
#  (32, 'Beatriz Watanabe', 57, 32, 81, 81, 98, 'El camino hacia la escuela', 'Drama', 139, datetime.date(1980, 10, 8), 98, 'Tatjana Pacheco', 44),
#  (141, 'Bianca Diniz', 68, 141, 85, 85, 179, 'El lamento de la cueva', 'Suspense', 71, datetime.date(1974, 3, 11), 179, 'Mina Barros', 56),
#  (141, 'Bianca Diniz', 68, 141, 154, 154, 6, 'El viaje de el laberinto', 'Misterio', 131, datetime.date(1973, 8, 3), 6, 'Han Xu', 82),
#  (77, 'Bianca Ivanov', 31, 77, 47, 47, 39, 'La búsqueda de el destino', 'Western', 108, datetime.date(1994, 5, 2), 39, 'Zoya Queiroz', 90),
#  (77, 'Bianca Ivanov', 31, 77, 18, 18, 22, 'La escalada de la paz', 'Misterio', 125, datetime.date(1994, 8, 22), 22, 'Giovanni Santana', 59),
#  (12, 'Chidike Lima', 65, 12, 235, 235, 177, 'La resurrección de el castillo', 'Drama', 116, datetime.date(1989, 12, 7), 177, 'Beatriz Kumar', 82),
#  (12, 'Chidike Lima', 65, 12, 65, 65, 127, 'La misión de el sol', 'Aventura', 117, datetime.date(1973, 7, 12), 127, 'Zafar Ramos', 80),
#  (144, 'Chiyoko Kumar', 67, 144, 254, 254, 64, 'El amanecer de el viaje', 'Romance', 115, datetime.date(1974, 11, 9), 64, 'Aarav Mendes', 32),
#  (118, 'Chiyoko Martinez', 58, 118, 294, 294, 151, 'El castillo de la luz', 'Romance', 128, datetime.date(2017, 10, 31), 151, 'Valeria Borges', 32),
#  (118, 'Chiyoko Martinez', 58, 118, 196, 196, 143, 'El camino hacia el jardín', 'Animación', 117, datetime.date(1981, 11, 2), 143, 'Ximena Kumar', 68),
#  (167, 'Chiyoko Yan', 49, 167, 265, 265, 158, 'La conquista de el sueño', 'Fantasía', 125, datetime.date(1970, 6, 25), 158, 'Umberto Figueiredo', 70),
#  (167, 'Chiyoko Yan', 49, 167, 89, 89, 86, 'El despertar de la cárcel', 'Ciencia ficción', 140, datetime.date(1972, 6, 7), 86, 'Rosa Dutta', 87),
#  (167, 'Chiyoko Yan', 49, 167, 29, 29, 4, 'La fortuna de la guerra', 'Aventura', 87, datetime.date(2022, 4, 17), 4, 'Oscar Rocha', 74),
#  (167, 'Chiyoko Yan', 49, 167, 69, 69, 64, 'El regreso de el muro', 'Aventura', 113, datetime.date(1981, 4, 15), 64, 'Aarav Mendes', 32),
#  (57, 'Darius Hernandez', 67, 57, 148, 148, 140, 'La resurrección de la estrella', 'Comedia', 144, datetime.date(2009, 11, 29), 140, 'Valeria Xu', 87),
#  (57, 'Darius Hernandez', 67, 57, 136, 136, 124, 'La historia de el sacrificio', 'Acción', 93, datetime.date(1997, 6, 21), 124, 'Parvati Etxebarria', 57),
#  (147, 'Darius Pacheco', 40, 147, 220, 220, 22, 'La invasión de el grito', 'Drama', 129, datetime.date(1962, 8, 8), 22, 'Giovanni Santana', 59),
#  (147, 'Darius Pacheco', 40, 147, 255, 255, 76, 'La llave de el renacimiento', 'Acción', 99, datetime.date(1988, 7, 30), 76, 'Jasmin Quintana', 71),
#  (147, 'Darius Pacheco', 40, 147, 181, 181, 73, 'La danza de la esperanza', 'Aventura', 125, datetime.date(2011, 3, 30), 73, 'Wang Borges', 40),
#  (175, 'Darya Lima', 22, 175, 42, 42, 36, 'La canción de el amanecer', 'Romance', 78, datetime.date(1973, 1, 15), 36, 'Xavier Vieira', 37),
#  (97, 'Darya Lopez', 24, 97, 268, 268, 148, 'El viaje de la neblina', 'Ciencia ficción', 74, datetime.date(1985, 2, 27), 148, 'Wan Mendes', 50),
#  (39, 'Dmitri Henriquez', 15, 39, 45, 45, 199, 'La redención de la nube', 'Fantasía', 98, datetime.date(1971, 4, 25), 199, 'Zara Teixeira', 88),
#  (39, 'Dmitri Henriquez', 15, 39, 221, 221, 194, 'El castillo de la profecía', 'Animación', 82, datetime.date(1987, 1, 15), 194, 'Elena Pacheco', 53),
#  (39, 'Dmitri Henriquez', 15, 39, 16, 16, 28, 'La travesía del océano de la gárgola', 'Drama', 148, datetime.date(1974, 1, 14), 28, 'Oscar Teixeira', 59),
#  (126, 'Dmitri Urbina', 30, 126, 110, 110, 98, 'El vuelo mágico de el sueño', 'Musical', 98, datetime.date(2001, 11, 18), 98, 'Tatjana Pacheco', 44),
#  (35, 'Elena Esteves', 29, 35, 82, 82, 116, 'El enigma de la soledad', 'Suspense', 107, datetime.date(2008, 1, 6), 116, 'Hiroko Ramos', 79),
#  (35, 'Elena Esteves', 29, 35, 92, 92, 31, 'El secreto de la bienvenida', 'Documental', 118, datetime.date(2000, 8, 15), 31, 'Mina Zambrano', 64),
#  (35, 'Elena Esteves', 29, 35, 152, 152, 185, 'El regreso de el héroe', 'Suspense', 94, datetime.date(1970, 12, 18), 185, 'Wan Correia', 32),
#  (35, 'Elena Esteves', 29, 35, 133, 133, 73, 'La travesía de la compañía', 'Romance', 70, datetime.date(2004, 11, 26), 73, 'Wang Borges', 40),
#  (35, 'Elena Esteves', 29, 35, 268, 268, 148, 'El viaje de la neblina', 'Ciencia ficción', 74, datetime.date(1985, 2, 27), 148, 'Wan Mendes', 50),
#  (105, 'Elena Goncalves', 61, 105, 66, 66, 193, 'La invasión de el valle', 'Musical', 80, datetime.date(1980, 2, 1), 193, 'Akira Montenegro', 43),
#  (105, 'Elena Goncalves', 61, 105, 113, 113, 7, 'La rebelión de el sueño', 'Documental', 84, datetime.date(2013, 11, 3), 7, 'Wilhelmina Estevez', 56),
#  (62, 'Elif Sousa', 17, 62, 284, 284, 34, 'La leyenda perdida de el sol', 'Western', 93, datetime.date(2023, 9, 11), 34, 'Mehmet Tan', 31),
#  (65, 'Emiko Carvalho', 23, 65, 164, 164, 82, 'El viajero de la fuga', 'Animación', 101, datetime.date(1964, 2, 1), 82, 'Vivek Ferreira', 72),
#  (65, 'Emiko Carvalho', 23, 65, 6, 6, 141, 'El cuento de hadas de el rey', 'Misterio', 70, datetime.date(1978, 1, 10), 141, 'Rashid Montenegro', 53),
#  (6, 'Emiko Hernandez', 61, 6, 257, 257, 79, 'La metamorfosis de el abismo', 'Suspense', 137, datetime.date(2004, 3, 31), 79, 'Omar Barros', 58),
#  (6, 'Emiko Hernandez', 61, 6, 229, 229, 33, 'El ritual de la profecía', 'Documental', 84, datetime.date(1989, 4, 27), 33, 'Gustavo Duarte', 55),
#  (6, 'Emiko Hernandez', 61, 6, 210, 210, 67, 'El misterio de la pesadilla', 'Suspense', 116, datetime.date(1996, 10, 31), 67, 'Khaled Dutta', 77),
#  (6, 'Emiko Hernandez', 61, 6, 33, 33, 65, 'El arco iris de la luz', 'Comedia', 70, datetime.date(1976, 12, 24), 65, 'Umar Qian', 90),
#  (51, 'Fabiana Figueiredo', 64, 51, 27, 27, 179, 'La canción de el renacimiento', 'Misterio', 137, datetime.date(1979, 2, 19), 179, 'Mina Barros', 56),
#  (51, 'Fabiana Figueiredo', 64, 51, 252, 252, 184, 'El último viaje de la heroína', 'Suspense', 89, datetime.date(1993, 7, 29), 184, 'Samir Janssen', 33),
#  (51, 'Fabiana Figueiredo', 64, 51, 141, 141, 92, 'El descubrimiento de el rincón', 'Terror', 74, datetime.date(1961, 6, 22), 92, 'Sakura Lopez', 78),
#  (135, 'Fadhila Lopez', 70, 135, 16, 16, 28, 'La travesía del océano de la gárgola', 'Drama', 148, datetime.date(1974, 1, 14), 28, 'Oscar Teixeira', 59),
#  (135, 'Fadhila Lopez', 70, 135, 75, 75, 159, 'La estrella fugaz de el amor', 'Acción', 130, datetime.date(1987, 9, 23), 159, 'Oscar Quintana', 42),
#  (135, 'Fadhila Lopez', 70, 135, 226, 226, 82, 'La senda de la corrupción', 'Suspense', 118, datetime.date(2000, 2, 28), 82, 'Vivek Ferreira', 72),
#  (48, 'Fadhila Montenegro', 45, 48, 66, 66, 193, 'La invasión de el valle', 'Musical', 80, datetime.date(1980, 2, 1), 193, 'Akira Montenegro', 43),
#  (48, 'Fadhila Montenegro', 45, 48, 61, 61, 94, 'La búsqueda de el enigma', 'Musical', 84, datetime.date(2013, 12, 30), 94, 'Gustavo Santana', 54),
#  (48, 'Fadhila Montenegro', 45, 48, 251, 251, 124, 'La fuga de la expedición', 'Fantasía', 116, datetime.date(2019, 8, 20), 124, 'Parvati Etxebarria', 57),
#  (48, 'Fadhila Montenegro', 45, 48, 193, 193, 160, 'La conquista de la resistencia', 'Acción', 82, datetime.date(2018, 3, 8), 160, 'Lakshmi Kawaguchi', 84),
#  (95, 'Fadhila Qian', 64, 95, 23, 23, 187, 'La odisea de la sonrisa', 'Aventura', 122, datetime.date(2005, 8, 27), 187, 'Khaled Vargas', 32),
#  (95, 'Fadhila Qian', 64, 95, 5, 5, 79, 'La travesía de el dragón', 'Terror', 111, datetime.date(1992, 11, 11), 79, 'Omar Barros', 58),
#  (95, 'Fadhila Qian', 64, 95, 241, 241, 94, 'La doncella de la traición', 'Drama', 127, datetime.date(2002, 5, 15), 94, 'Gustavo Santana', 54),
#  (95, 'Fadhila Qian', 64, 95, 246, 246, 29, 'El misterio de el mago', 'Animación', 107, datetime.date(2018, 1, 31), 29, 'Xin Zhang', 41),
#  (95, 'Fadhila Qian', 64, 95, 120, 120, 60, 'El hechizo de el descubrimiento', 'Misterio', 113, datetime.date(2013, 4, 17), 60, 'Irina Joaquim', 90),
#  (54, 'Fatemeh Hernandez', 18, 54, 23, 23, 187, 'La odisea de la sonrisa', 'Aventura', 122, datetime.date(2005, 8, 27), 187, 'Khaled Vargas', 32),
#  (54, 'Fatemeh Hernandez', 18, 54, 184, 184, 138, 'El último viaje de el rincón', 'Comedia', 136, datetime.date(2011, 2, 3), 138, 'Patricia Petrov', 83),
#  (176, 'Genghis Petrov', 20, 176, 19, 19, 55, 'El pacto de el destino', 'Documental', 150, datetime.date(1984, 6, 17), 55, 'Ursula Duarte', 42),
#  (176, 'Genghis Petrov', 20, 176, 3, 3, 96, 'La maldición del vampiro de el laberinto', 'Western', 76, datetime.date(2002, 11, 25), 96, 'Natalia Etxebarria', 51),
#  (98, 'Giovanni Yamamoto', 58, 98, 34, 34, 70, 'El eclipse de el dragón', 'Documental', 147, datetime.date(1991, 12, 10), 70, 'Leonardo Yilmaz', 54),
#  (98, 'Giovanni Yamamoto', 58, 98, 24, 24, 122, 'El castillo de la cascada', 'Western', 117, datetime.date(1988, 8, 26), 122, 'Omar Hernandez', 39),
#  (98, 'Giovanni Yamamoto', 58, 98, 165, 165, 46, 'El descubrimiento de el sacrificio', 'Comedia', 127, datetime.date(1976, 3, 27), 46, 'Zoya Santana', 90),
#  (98, 'Giovanni Yamamoto', 58, 98, 269, 269, 130, 'El camino hacia la batalla', 'Musical', 100, datetime.date(1968, 8, 19), 130, 'Zoya Olivares', 34),
#  (89, 'Giovanni Yan', 31, 89, 283, 283, 51, 'El tesoro escondido de la mariposa', 'Fantasía', 90, datetime.date(2002, 11, 14), 51, 'Fabiana Borges', 80),
#  (89, 'Giovanni Yan', 31, 89, 270, 270, 12, 'La travesía del océano de la bruma', 'Ciencia ficción', 118, datetime.date(2016, 9, 28), 12, 'Katarina Xavier', 59),
#  (89, 'Giovanni Yan', 31, 89, 273, 273, 143, 'La resurrección de la cascada', 'Documental', 75, datetime.date(1964, 7, 23), 143, 'Ximena Kumar', 68),
#  (106, 'Gustavo Lopez', 27, 106, 58, 58, 180, 'La metamorfosis de la guerra', 'Romance', 113, datetime.date(1964, 6, 8), 180, 'Ursula Yamamoto', 59),
#  (106, 'Gustavo Lopez', 27, 106, 89, 89, 86, 'El despertar de la cárcel', 'Ciencia ficción', 140, datetime.date(1972, 6, 7), 86, 'Rosa Dutta', 87),
#  (170, 'Gustavo Nguyen', 25, 170, 258, 258, 103, 'El espejismo de el grito', 'Documental', 85, datetime.date(1980, 7, 15), 103, 'Xin Jimenez', 63),
#  (170, 'Gustavo Nguyen', 25, 170, 132, 132, 21, 'El tesoro de la estrella', 'Ciencia ficción', 132, datetime.date(1961, 2, 8), 21, 'Emiko Yan', 90),
#  (170, 'Gustavo Nguyen', 25, 170, 190, 190, 126, 'El arco iris de la caída', 'Documental', 142, datetime.date(1971, 4, 18), 126, 'Katarina Henriquez', 51),
#  (170, 'Gustavo Nguyen', 25, 170, 137, 137, 38, 'El hechizo de la fortuna', 'Western', 109, datetime.date(2005, 1, 31), 38, 'Xavier Uchoa', 73),
#  (170, 'Gustavo Nguyen', 25, 170, 202, 202, 72, 'La escalada de la pesadilla', 'Animación', 70, datetime.date(2003, 2, 11), 72, 'Theresa Qian', 73),
#  (170, 'Gustavo Nguyen', 25, 170, 249, 249, 25, 'El espejismo de el guardián', 'Animación', 103, datetime.date(1969, 6, 2), 25, 'Katarina Velez', 69),
#  (9, 'Gustavo Yamamoto', 45, 9, 139, 139, 65, 'La tormenta de la bruja', 'Romance', 137, datetime.date(1965, 11, 4), 65, 'Umar Qian', 90),
#  (61, 'Gustavo Yan', 26, 61, 180, 180, 181, 'El tesoro escondido de la ciudad', 'Acción', 72, datetime.date(2004, 6, 20), 181, 'Fabiana Xavier', 39),
#  (61, 'Gustavo Yan', 26, 61, 274, 274, 104, 'El despertar de la oscuridad', 'Drama', 75, datetime.date(1966, 4, 28), 104, 'Vivek Goncalves', 63),
#  (168, 'Han Alvarez', 65, 168, 176, 176, 137, 'Las aventuras de el río', 'Terror', 135, datetime.date(1989, 10, 27), 137, 'Samir Carvalho', 42),
#  (168, 'Han Alvarez', 65, 168, 120, 120, 60, 'El hechizo de el descubrimiento', 'Misterio', 113, datetime.date(2013, 4, 17), 60, 'Irina Joaquim', 90),
#  (168, 'Han Alvarez', 65, 168, 80, 80, 161, 'La maldición de la traición', 'Suspense', 77, datetime.date(1967, 3, 31), 161, 'Rashid Mendes', 69),
#  (168, 'Han Alvarez', 65, 168, 197, 197, 39, 'La danza macabra de la aventura', 'Ciencia ficción', 149, datetime.date(1983, 5, 27), 39, 'Zoya Queiroz', 90),
#  (169, 'Han Iglesias', 52, 169, 194, 194, 84, 'El refugio de el sueño', 'Drama', 134, datetime.date(1968, 11, 24), 84, 'Parvati Vieira', 73),
#  (169, 'Han Iglesias', 52, 169, 74, 74, 83, 'La búsqueda del tesoro de el descubrimiento', 'Misterio', 138, datetime.date(2004, 2, 7), 83, 'Vivek Zapata', 68),
#  (169, 'Han Iglesias', 52, 169, 106, 106, 178, 'La batalla de la cripta', 'Documental', 126, datetime.date(2009, 5, 12), 178, 'Qiu Rodriguez', 66),
#  (169, 'Han Iglesias', 52, 169, 242, 242, 17, 'El espejismo de la gruta', 'Western', 75, datetime.date(1978, 7, 7), 17, 'Umberto Bianchi', 31),
#  (150, 'Han Joaquim', 25, 150, 203, 203, 32, 'La senda de el cielo', 'Misterio', 114, datetime.date(1997, 6, 16), 32, 'Zoya Bianchi', 33),
#  (150, 'Han Joaquim', 25, 150, 56, 56, 53, 'La trampa de la fortuna', 'Fantasía', 136, datetime.date(2004, 2, 6), 53, 'Darya Martinez', 72),
#  (178, 'Hanako Alvarez', 26, 178, 269, 269, 130, 'El camino hacia la batalla', 'Musical', 100, datetime.date(1968, 8, 19), 130, 'Zoya Olivares', 34),
#  (178, 'Hanako Alvarez', 26, 178, 83, 83, 27, 'La fuga de la profecía', 'Western', 98, datetime.date(1997, 12, 6), 27, 'Wilhelmina Quintana', 90),
#  (178, 'Hanako Alvarez', 26, 178, 128, 128, 19, 'El secreto oscuro de el cielo', 'Romance', 150, datetime.date(1981, 3, 9), 19, 'Tatiana Estevez', 81),
#  (178, 'Hanako Alvarez', 26, 178, 27, 27, 179, 'La canción de el renacimiento', 'Misterio', 137, datetime.date(1979, 2, 19), 179, 'Mina Barros', 56),
#  (178, 'Hanako Alvarez', 26, 178, 81, 81, 98, 'El camino hacia la escuela', 'Drama', 139, datetime.date(1980, 10, 8), 98, 'Tatjana Pacheco', 44),
#  (125, 'Ilya Ivanov', 23, 125, 277, 277, 169, 'La travesía del océano de la desgracia', 'Suspense', 133, datetime.date(2022, 12, 19), 169, 'Javier Etxebarria', 63),
#  (81, 'Ilya Martinez', 30, 81, 52, 52, 156, 'El lamento de la oscuridad', 'Aventura', 87, datetime.date(1960, 5, 29), 156, 'Wan Gao', 84),
#  (81, 'Ilya Martinez', 30, 81, 238, 238, 146, 'La misión de el amor', 'Animación', 133, datetime.date(2018, 5, 29), 146, 'Zoya Zambrano', 81),
#  (81, 'Ilya Martinez', 30, 81, 145, 145, 65, 'El resurgimiento de el explorador', 'Suspense', 147, datetime.date(2011, 10, 21), 65, 'Umar Qian', 90),
#  (81, 'Ilya Martinez', 30, 81, 37, 37, 20, 'La búsqueda del tesoro de la profecía', 'Animación', 114, datetime.date(1989, 6, 1), 20, 'Valeria Carvalho', 59),
#  (104, 'Ilya Nunes', 34, 104, 69, 69, 64, 'El regreso de el muro', 'Aventura', 113, datetime.date(1981, 4, 15), 64, 'Aarav Mendes', 32),
#  (104, 'Ilya Nunes', 34, 104, 39, 39, 114, 'El príncipe de el destino', 'Musical', 120, datetime.date(2022, 4, 1), 114, 'Valentina Mendes', 44),
#  (104, 'Ilya Nunes', 34, 104, 154, 154, 6, 'El viaje de el laberinto', 'Misterio', 131, datetime.date(1973, 8, 3), 6, 'Han Xu', 82),
#  (163, 'Ilya Velez', 29, 163, 85, 85, 179, 'El lamento de la cueva', 'Suspense', 71, datetime.date(1974, 3, 11), 179, 'Mina Barros', 56),
#  (163, 'Ilya Velez', 29, 163, 284, 284, 34, 'La leyenda perdida de el sol', 'Western', 93, datetime.date(2023, 9, 11), 34, 'Mehmet Tan', 31),
#  (163, 'Ilya Velez', 29, 163, 2, 2, 91, 'La invasión de el árbol', 'Aventura', 71, datetime.date(1980, 8, 28), 91, 'Khaled Oliveira', 67),
#  (50, 'Ilya Zapata', 41, 50, 81, 81, 98, 'El camino hacia la escuela', 'Drama', 139, datetime.date(1980, 10, 8), 98, 'Tatjana Pacheco', 44),
#  (159, 'Isa Mendes', 70, 159, 125, 125, 49, 'El descubrimiento de la aldea', 'Western', 108, datetime.date(1975, 12, 12), 49, 'Tatjana Petrov', 39),
#  (159, 'Isa Mendes', 70, 159, 180, 180, 181, 'El tesoro escondido de la ciudad', 'Acción', 72, datetime.date(2004, 6, 20), 181, 'Fabiana Xavier', 39),
#  (156, 'Isa Zapata', 24, 156, 58, 58, 180, 'La metamorfosis de la guerra', 'Romance', 113, datetime.date(1964, 6, 8), 180, 'Ursula Yamamoto', 59),
#  (156, 'Isa Zapata', 24, 156, 214, 214, 103, 'El eclipse de la clave', 'Acción', 101, datetime.date(1992, 6, 8), 103, 'Xin Jimenez', 63),
#  (156, 'Isa Zapata', 24, 156, 159, 159, 65, 'El caballero de el enigma', 'Terror', 74, datetime.date(1966, 12, 28), 65, 'Umar Qian', 90),
#  (102, 'Jasmin Borges', 46, 102, 67, 67, 13, 'La canción de la amistad', 'Musical', 129, datetime.date(2019, 2, 16), 13, 'Orhan Etxebarria', 62),
#  (164, 'Jasmin Xia', 64, 164, 101, 101, 76, 'El cuento de hadas de el tesoro', 'Ciencia ficción', 89, datetime.date(2003, 8, 14), 76, 'Jasmin Quintana', 71),
#  (164, 'Jasmin Xia', 64, 164, 209, 209, 100, 'La escalada de la aldea', 'Drama', 77, datetime.date(1973, 8, 11), 100, 'Abdullah Ramos', 72),
#  (164, 'Jasmin Xia', 64, 164, 217, 217, 8, 'El tesoro de el vuelo', 'Suspense', 137, datetime.date(1991, 1, 13), 8, 'Quentin Janssen', 81),
#  (164, 'Jasmin Xia', 64, 164, 164, 164, 82, 'El viajero de la fuga', 'Animación', 101, datetime.date(1964, 2, 1), 82, 'Vivek Ferreira', 72),
#  (164, 'Jasmin Xia', 64, 164, 292, 292, 139, 'El bosque encantado de la ciudad', 'Comedia', 79, datetime.date(2001, 3, 5), 139, 'Lakshmi Abadi', 77),
#  (26, 'Javier Quintana', 46, 26, 27, 27, 179, 'La canción de el renacimiento', 'Misterio', 137, datetime.date(1979, 2, 19), 179, 'Mina Barros', 56),
#  (26, 'Javier Quintana', 46, 26, 170, 170, 196, 'El último viaje de el volcán', 'Fantasía', 130, datetime.date(2011, 9, 12), 196, 'Zafar Kawaguchi', 87),
#  (26, 'Javier Quintana', 46, 26, 202, 202, 72, 'La escalada de la pesadilla', 'Animación', 70, datetime.date(2003, 2, 11), 72, 'Theresa Qian', 73),
#  (157, 'Javier Vargas', 18, 157, 166, 166, 168, 'La llegada de la promesa', 'Documental', 95, datetime.date(2014, 11, 10), 168, 'Ilya Olivares', 41),
#  (157, 'Javier Vargas', 18, 157, 280, 280, 182, 'El refugio de la selva', 'Musical', 131, datetime.date(1974, 5, 3), 182, 'Han Jimenez', 66),
#  (157, 'Javier Vargas', 18, 157, 99, 99, 198, 'La fuente de el fuego', 'Comedia', 101, datetime.date(1982, 3, 28), 198, 'Rania Figueiredo', 30),
#  (87, 'Jin Barros', 25, 87, 125, 125, 49, 'El descubrimiento de la aldea', 'Western', 108, datetime.date(1975, 12, 12), 49, 'Tatjana Petrov', 39),
#  (31, 'Jin Fernandes', 24, 31, 181, 181, 73, 'La danza de la esperanza', 'Aventura', 125, datetime.date(2011, 3, 30), 73, 'Wang Borges', 40),
#  (31, 'Jin Fernandes', 24, 31, 43, 43, 75, 'El secreto de la puerta', 'Aventura', 130, datetime.date(1961, 5, 9), 75, 'Akira Duarte', 90),
#  (31, 'Jin Fernandes', 24, 31, 111, 111, 91, 'La búsqueda de la sirena', 'Aventura', 95, datetime.date(1967, 5, 6), 91, 'Khaled Oliveira', 67),
#  (31, 'Jin Fernandes', 24, 31, 28, 28, 93, 'La estirpe de el perdón', 'Aventura', 112, datetime.date(1979, 9, 23), 93, 'Qiu Lima', 76),
#  (25, 'Jin Kawaguchi', 18, 25, 195, 195, 55, 'La misión de el puente', 'Aventura', 74, datetime.date(1990, 4, 24), 55, 'Ursula Duarte', 42),
#  (25, 'Jin Kawaguchi', 18, 25, 300, 300, 134, 'El refugio de la magia', 'Romance', 120, datetime.date(1997, 5, 24), 134, 'Jin Martinez', 80),
#  (25, 'Jin Kawaguchi', 18, 25, 163, 163, 132, 'La búsqueda del tesoro de el guardián', 'Aventura', 70, datetime.date(1992, 10, 30), 132, 'Elif Yilmaz', 63),
#  (152, 'Kamala Almeida', 35, 152, 117, 117, 185, 'La maldición del vampiro de la pesadilla', 'Drama', 80, datetime.date(2018, 12, 4), 185, 'Wan Correia', 32),
#  (152, 'Kamala Almeida', 35, 152, 57, 57, 91, 'El misterio de el cielo', 'Romance', 131, datetime.date(2021, 1, 10), 91, 'Khaled Oliveira', 67),
#  (174, 'Kamala Dutta', 55, 174, 169, 169, 91, 'La doncella de la corona', 'Documental', 96, datetime.date(2021, 11, 26), 91, 'Khaled Oliveira', 67),
#  (174, 'Kamala Dutta', 55, 174, 210, 210, 67, 'El misterio de la pesadilla', 'Suspense', 116, datetime.date(1996, 10, 31), 67, 'Khaled Dutta', 77),
#  (174, 'Kamala Dutta', 55, 174, 111, 111, 91, 'La búsqueda de la sirena', 'Aventura', 95, datetime.date(1967, 5, 6), 91, 'Khaled Oliveira', 67),
#  (191, 'Kamala Velez', 48, 191, 109, 109, 32, 'La maldición del vampiro de la esperanza', 'Documental', 84, datetime.date(2023, 11, 29), 32, 'Zoya Bianchi', 33),
#  (191, 'Kamala Velez', 48, 191, 197, 197, 39, 'La danza macabra de la aventura', 'Ciencia ficción', 149, datetime.date(1983, 5, 27), 39, 'Zoya Queiroz', 90),
#  (191, 'Kamala Velez', 48, 191, 184, 184, 138, 'El último viaje de el rincón', 'Comedia', 136, datetime.date(2011, 2, 3), 138, 'Patricia Petrov', 83),
#  (76, 'Katarina Hernandez', 16, 76, 59, 59, 109, 'El ritual de el sacrificio', 'Documental', 108, datetime.date(1962, 2, 1), 109, 'Darius Barros', 43),
#  (76, 'Katarina Hernandez', 16, 76, 83, 83, 27, 'La fuga de la profecía', 'Western', 98, datetime.date(1997, 12, 6), 27, 'Wilhelmina Quintana', 90),
#  (76, 'Katarina Hernandez', 16, 76, 218, 218, 135, 'La fuente de el árbol', 'Animación', 110, datetime.date(2013, 3, 31), 135, 'Jin Esteves', 39),
#  (76, 'Katarina Hernandez', 16, 76, 255, 255, 76, 'La llave de el renacimiento', 'Acción', 99, datetime.date(1988, 7, 30), 76, 'Jasmin Quintana', 71),
#  (76, 'Katarina Hernandez', 16, 76, 270, 270, 12, 'La travesía del océano de la bruma', 'Ciencia ficción', 118, datetime.date(2016, 9, 28), 12, 'Katarina Xavier', 59),
#  (165, 'Katarina Petrov', 33, 165, 106, 106, 178, 'La batalla de la cripta', 'Documental', 126, datetime.date(2009, 5, 12), 178, 'Qiu Rodriguez', 66),
#  (165, 'Katarina Petrov', 33, 165, 267, 267, 148, 'La senda de el perdón', 'Comedia', 125, datetime.date(2021, 6, 25), 148, 'Wan Mendes', 50),
#  (119, 'Khaled Henriquez', 26, 119, 223, 223, 38, 'La danza de el valle', 'Documental', 86, datetime.date(1968, 10, 24), 38, 'Xavier Uchoa', 73),
#  (119, 'Khaled Henriquez', 26, 119, 55, 55, 23, 'La travesía sin retorno de la desgracia', 'Aventura', 108, datetime.date(2006, 6, 20), 23, 'Yusef Figueiredo', 35),
#  (119, 'Khaled Henriquez', 26, 119, 59, 59, 109, 'El ritual de el sacrificio', 'Documental', 108, datetime.date(1962, 2, 1), 109, 'Darius Barros', 43),
#  (132, 'Khaled Kumar', 23, 132, 104, 104, 199, 'La llave de la ciudad', 'Ciencia ficción', 80, datetime.date(1969, 5, 18), 199, 'Zara Teixeira', 88),
#  (132, 'Khaled Kumar', 23, 132, 88, 88, 121, 'La búsqueda de la desgracia', 'Misterio', 91, datetime.date(1974, 2, 2), 121, 'Katarina Iglesias', 32),
#  (132, 'Khaled Kumar', 23, 132, 47, 47, 39, 'La búsqueda de el destino', 'Western', 108, datetime.date(1994, 5, 2), 39, 'Zoya Queiroz', 90),
#  (177, 'Khaled Ueno', 15, 177, 186, 186, 154, 'La danza macabra de la ola', 'Acción', 126, datetime.date(1965, 6, 12), 154, 'Hanako Gomes', 78),
#  (177, 'Khaled Ueno', 15, 177, 32, 32, 84, 'El tesoro de la caverna', 'Comedia', 130, datetime.date(1980, 4, 10), 84, 'Parvati Vieira', 73),
#  (177, 'Khaled Ueno', 15, 177, 53, 53, 182, 'El prisionero de el laberinto', 'Suspense', 87, datetime.date(1966, 4, 14), 182, 'Han Jimenez', 66),
#  (17, 'Lakshmi Gomes', 47, 17, 163, 163, 132, 'La búsqueda del tesoro de el guardián', 'Aventura', 70, datetime.date(1992, 10, 30), 132, 'Elif Yilmaz', 63),
#  (17, 'Lakshmi Gomes', 47, 17, 168, 168, 143, 'El prisionero de la mariposa', 'Misterio', 78, datetime.date(1989, 2, 26), 143, 'Ximena Kumar', 68),
#  (160, 'Lakshmi Lima', 34, 160, 94, 94, 88, 'La travesura de la estrella', 'Terror', 135, datetime.date(1971, 4, 20), 88, 'Chidike Yan', 56),
#  (160, 'Lakshmi Lima', 34, 160, 37, 37, 20, 'La búsqueda del tesoro de la profecía', 'Animación', 114, datetime.date(1989, 6, 1), 20, 'Valeria Carvalho', 59),
#  (160, 'Lakshmi Lima', 34, 160, 130, 130, 188, 'La canción de el puente', 'Terror', 128, datetime.date(1999, 6, 28), 188, 'Jin Tan', 80),
#  (33, 'Lakshmi Mendes', 24, 33, 50, 50, 172, 'El guardián de la bailarina', 'Romance', 86, datetime.date(2004, 3, 9), 172, 'Hanako Ramos', 54),
#  (91, 'Lakshmi Nogueira', 37, 91, 67, 67, 13, 'La canción de la amistad', 'Musical', 129, datetime.date(2019, 2, 16), 13, 'Orhan Etxebarria', 62),
#  (91, 'Lakshmi Nogueira', 37, 91, 154, 154, 6, 'El viaje de el laberinto', 'Misterio', 131, datetime.date(1973, 8, 3), 6, 'Han Xu', 82),
#  (91, 'Lakshmi Nogueira', 37, 91, 135, 135, 164, 'La canción de la soledad', 'Western', 125, datetime.date(2009, 9, 23), 164, 'Genghis Lima', 56),
#  (74, 'Lakshmi Yamamoto', 45, 74, 60, 60, 52, 'El camino hacia la noche', 'Fantasía', 110, datetime.date(1992, 7, 13), 52, 'Katarina Qian', 41),
#  (74, 'Lakshmi Yamamoto', 45, 74, 84, 84, 99, 'La trampa de la reina', 'Acción', 100, datetime.date(1973, 6, 19), 99, 'Fadhila Qian', 45),
#  (194, 'Leonardo Correia', 48, 194, 194, 194, 84, 'El refugio de el sueño', 'Drama', 134, datetime.date(1968, 11, 24), 84, 'Parvati Vieira', 73),
#  (194, 'Leonardo Correia', 48, 194, 167, 167, 149, 'La escalada de la mariposa', 'Misterio', 139, datetime.date(1974, 11, 22), 149, 'Mehmet Tan', 76),
#  (194, 'Leonardo Correia', 48, 194, 64, 64, 164, 'La trampa de la bestia', 'Terror', 72, datetime.date(1965, 2, 26), 164, 'Genghis Lima', 56),
#  (194, 'Leonardo Correia', 48, 194, 13, 13, 92, 'La leyenda de la montaña', 'Suspense', 139, datetime.date(2018, 2, 5), 92, 'Sakura Lopez', 78),
#  (173, 'Leonardo Cruz', 28, 173, 13, 13, 92, 'La leyenda de la montaña', 'Suspense', 139, datetime.date(2018, 2, 5), 92, 'Sakura Lopez', 78),
#  (173, 'Leonardo Cruz', 28, 173, 176, 176, 137, 'Las aventuras de el río', 'Terror', 135, datetime.date(1989, 10, 27), 137, 'Samir Carvalho', 42),
#  (190, 'Leonardo Fernandes', 41, 190, 150, 150, 125, 'La fuente de la escuela', 'Terror', 148, datetime.date(1984, 1, 4), 125, 'Yasmin Martinez', 87),
#  (190, 'Leonardo Fernandes', 41, 190, 251, 251, 124, 'La fuga de la expedición', 'Fantasía', 116, datetime.date(2019, 8, 20), 124, 'Parvati Etxebarria', 57),
#  (190, 'Leonardo Fernandes', 41, 190, 212, 212, 22, 'La doncella de el viaje', 'Musical', 107, datetime.date(1990, 2, 2), 22, 'Giovanni Santana', 59),
#  (190, 'Leonardo Fernandes', 41, 190, 7, 7, 48, 'El grito de el mago', 'Animación', 123, datetime.date(2019, 3, 24), 48, 'Xin Tan', 83),
#  (5, 'Leonardo Ortega', 53, 5, 208, 208, 24, 'La redención de el muro', 'Suspense', 103, datetime.date(1996, 12, 30), 24, 'Aarav Queiroz', 51),
#  (5, 'Leonardo Ortega', 53, 5, 219, 219, 129, 'El vuelo de el amor', 'Musical', 101, datetime.date(1975, 8, 14), 129, 'Patricia Ferreira', 66),
#  (151, 'Leonardo Zapata', 47, 151, 38, 38, 92, 'La doncella de el ángel', 'Romance', 100, datetime.date(1979, 1, 22), 92, 'Sakura Lopez', 78),
#  (151, 'Leonardo Zapata', 47, 151, 210, 210, 67, 'El misterio de la pesadilla', 'Suspense', 116, datetime.date(1996, 10, 31), 67, 'Khaled Dutta', 77),
#  (82, 'Mehmet Kumar', 58, 82, 99, 99, 198, 'La fuente de el fuego', 'Comedia', 101, datetime.date(1982, 3, 28), 198, 'Rania Figueiredo', 30),
#  (82, 'Mehmet Kumar', 58, 82, 200, 200, 153, 'La leyenda perdida de la montaña', 'Drama', 75, datetime.date(1994, 4, 21), 153, 'Chidike Yamamoto', 73),
#  (140, 'Mehmet Velez', 22, 140, 116, 116, 88, 'El ritual de la venganza', 'Documental', 138, datetime.date(1993, 7, 24), 88, 'Chidike Yan', 56),
#  (140, 'Mehmet Velez', 22, 140, 23, 23, 187, 'La odisea de la sonrisa', 'Aventura', 122, datetime.date(2005, 8, 27), 187, 'Khaled Vargas', 32),
#  (140, 'Mehmet Velez', 22, 140, 201, 201, 145, 'El cuento de hadas de la estrella', 'Acción', 109, datetime.date(2015, 2, 7), 145, 'Tatjana Rodriguez', 60),
#  (22, 'Mehmet Zapata', 20, 22, 233, 233, 32, 'La travesía sin retorno de la trampa', 'Musical', 95, datetime.date(1988, 10, 30), 32, 'Zoya Bianchi', 33),
#  (22, 'Mehmet Zapata', 20, 22, 202, 202, 72, 'La escalada de la pesadilla', 'Animación', 70, datetime.date(2003, 2, 11), 72, 'Theresa Qian', 73),
#  (23, 'Mikhail Inácio', 56, 23, 195, 195, 55, 'La misión de el puente', 'Aventura', 74, datetime.date(1990, 4, 24), 55, 'Ursula Duarte', 42),
#  (23, 'Mikhail Inácio', 56, 23, 56, 56, 53, 'La trampa de la fortuna', 'Fantasía', 136, datetime.date(2004, 2, 6), 53, 'Darya Martinez', 72),
#  (23, 'Mikhail Inácio', 56, 23, 138, 138, 187, 'La travesía del océano de la estrella', 'Romance', 88, datetime.date(1963, 3, 2), 187, 'Khaled Vargas', 32),
#  (23, 'Mikhail Inácio', 56, 23, 212, 212, 22, 'La doncella de el viaje', 'Musical', 107, datetime.date(1990, 2, 2), 22, 'Giovanni Santana', 59),
#  (121, 'Mikhail Mendes', 59, 121, 19, 19, 55, 'El pacto de el destino', 'Documental', 150, datetime.date(1984, 6, 17), 55, 'Ursula Duarte', 42),
#  (121, 'Mikhail Mendes', 59, 121, 160, 160, 93, 'El caballero de el ángel', 'Fantasía', 129, datetime.date(1965, 5, 2), 93, 'Qiu Lima', 76),
#  (121, 'Mikhail Mendes', 59, 121, 156, 156, 116, 'La conquista de el faro', 'Drama', 108, datetime.date(1977, 1, 22), 116, 'Hiroko Ramos', 79),
#  (121, 'Mikhail Mendes', 59, 121, 233, 233, 32, 'La travesía sin retorno de la trampa', 'Musical', 95, datetime.date(1988, 10, 30), 32, 'Zoya Bianchi', 33),
#  (121, 'Mikhail Mendes', 59, 121, 149, 149, 172, 'La danza de el río', 'Romance', 132, datetime.date(2022, 10, 30), 172, 'Hanako Ramos', 54),
#  (108, 'Mikhail Ortega', 61, 108, 205, 205, 130, 'El bosque encantado de la sirena', 'Fantasía', 117, datetime.date(1977, 12, 25), 130, 'Zoya Olivares', 34),
#  (108, 'Mikhail Ortega', 61, 108, 231, 231, 95, 'La fuga de la estrella fugaz', 'Terror', 112, datetime.date(2003, 6, 21), 95, 'Yusef Ortega', 86),
#  (40, 'Mikhail Xavier', 15, 40, 135, 135, 164, 'La canción de la soledad', 'Western', 125, datetime.date(2009, 9, 23), 164, 'Genghis Lima', 56),
#  (116, 'Mina Almeida', 64, 116, 188, 188, 119, 'El espejismo de la muralla', 'Documental', 96, datetime.date(1965, 8, 29), 119, 'Chen Rocha', 42),
#  (116, 'Mina Almeida', 64, 116, 165, 165, 46, 'El descubrimiento de el sacrificio', 'Comedia', 127, datetime.date(1976, 3, 27), 46, 'Zoya Santana', 90),
#  (116, 'Mina Almeida', 64, 116, 34, 34, 70, 'El eclipse de el dragón', 'Documental', 147, datetime.date(1991, 12, 10), 70, 'Leonardo Yilmaz', 54),
#  (200, 'Mina Ferreira', 49, 200, 24, 24, 122, 'El castillo de la cascada', 'Western', 117, datetime.date(1988, 8, 26), 122, 'Omar Hernandez', 39),
#  (10, 'Mina Figueiredo', 15, 10, 223, 223, 38, 'La danza de el valle', 'Documental', 86, datetime.date(1968, 10, 24), 38, 'Xavier Uchoa', 73),
#  (138, 'Mina Teles', 36, 138, 202, 202, 72, 'La escalada de la pesadilla', 'Animación', 70, datetime.date(2003, 2, 11), 72, 'Theresa Qian', 73),
#  (138, 'Mina Teles', 36, 138, 192, 192, 152, 'La redención de el muro', 'Suspense', 146, datetime.date(1961, 3, 8), 152, 'Nadia Pacheco', 64),
#  (138, 'Mina Teles', 36, 138, 120, 120, 60, 'El hechizo de el descubrimiento', 'Misterio', 113, datetime.date(2013, 4, 17), 60, 'Irina Joaquim', 90),
#  (138, 'Mina Teles', 36, 138, 64, 64, 164, 'La trampa de la bestia', 'Terror', 72, datetime.date(1965, 2, 26), 164, 'Genghis Lima', 56),
#  (171, 'Nadia Teixeira', 43, 171, 34, 34, 70, 'El eclipse de el dragón', 'Documental', 147, datetime.date(1991, 12, 10), 70, 'Leonardo Yilmaz', 54),
#  (171, 'Nadia Teixeira', 43, 171, 149, 149, 172, 'La danza de el río', 'Romance', 132, datetime.date(2022, 10, 30), 172, 'Hanako Ramos', 54),
#  (166, 'Natalia Hidalgo', 63, 166, 156, 156, 116, 'La conquista de el faro', 'Drama', 108, datetime.date(1977, 1, 22), 116, 'Hiroko Ramos', 79),
#  (166, 'Natalia Hidalgo', 63, 166, 173, 173, 112, 'La profecía de la traición', 'Drama', 79, datetime.date(2018, 9, 5), 112, 'Alessandro Lopez', 73),
#  (166, 'Natalia Hidalgo', 63, 166, 251, 251, 124, 'La fuga de la expedición', 'Fantasía', 116, datetime.date(2019, 8, 20), 124, 'Parvati Etxebarria', 57),
#  (185, 'Natalia Zapata', 29, 185, 247, 247, 86, 'El tesoro de la traición', 'Musical', 138, datetime.date(1968, 1, 26), 86, 'Rosa Dutta', 87),
#  (185, 'Natalia Zapata', 29, 185, 105, 105, 72, 'El cuento de hadas de la cripta', 'Comedia', 99, datetime.date(1979, 9, 29), 72, 'Theresa Qian', 73),
#  (185, 'Natalia Zapata', 29, 185, 43, 43, 75, 'El secreto de la puerta', 'Aventura', 130, datetime.date(1961, 5, 9), 75, 'Akira Duarte', 90),
#  (195, 'Nina Cruz', 62, 195, 298, 298, 147, 'La travesía sin retorno de el perdón', 'Terror', 144, datetime.date(1974, 1, 19), 147, 'Umar Pereira', 66),
#  (195, 'Nina Cruz', 62, 195, 88, 88, 121, 'La búsqueda de la desgracia', 'Misterio', 91, datetime.date(1974, 2, 2), 121, 'Katarina Iglesias', 32),
#  (154, 'Nina Montenegro', 31, 154, 214, 214, 103, 'El eclipse de la clave', 'Acción', 101, datetime.date(1992, 6, 8), 103, 'Xin Jimenez', 63),
#  (154, 'Nina Montenegro', 31, 154, 234, 234, 24, 'La leyenda de la oscuridad', 'Musical', 94, datetime.date(2018, 6, 10), 24, 'Aarav Queiroz', 51),
#  (154, 'Nina Montenegro', 31, 154, 299, 299, 167, 'El lamento de el héroe', 'Drama', 100, datetime.date(2018, 12, 21), 167, 'Mina Fernandes', 35),
#  (154, 'Nina Montenegro', 31, 154, 4, 4, 184, 'La travesura de la estrella', 'Terror', 136, datetime.date(1961, 5, 13), 184, 'Samir Janssen', 33),
#  (154, 'Nina Montenegro', 31, 154, 25, 25, 78, 'La rebelión de el castillo', 'Ciencia ficción', 136, datetime.date(1994, 5, 8), 78, 'Wang Abadi', 66),
#  (154, 'Nina Montenegro', 31, 154, 122, 122, 175, 'La cripta de el viaje', 'Animación', 88, datetime.date(1967, 9, 19), 175, 'Abdullah Xu', 64),
#  (154, 'Nina Montenegro', 31, 154, 178, 178, 77, 'El secreto oscuro de la travesía', 'Terror', 84, datetime.date(2011, 8, 6), 77, 'Bianca Rocha', 52),
#  (4, 'Nina Ueno', 38, 4, 124, 124, 93, 'El secreto oscuro de la estrella fugaz', 'Romance', 95, datetime.date(1983, 8, 1), 93, 'Qiu Lima', 76),
#  (4, 'Nina Ueno', 38, 4, 211, 211, 38, 'El destino de la caída', 'Suspense', 80, datetime.date(1989, 12, 18), 38, 'Xavier Uchoa', 73),
#  (183, 'Omar Almeida', 15, 183, 130, 130, 188, 'La canción de el puente', 'Terror', 128, datetime.date(1999, 6, 28), 188, 'Jin Tan', 80),
#  (183, 'Omar Almeida', 15, 183, 204, 204, 197, 'El tesoro escondido de el valle', 'Ciencia ficción', 107, datetime.date(1974, 9, 27), 197, 'Yuri Wu', 73),
#  (183, 'Omar Almeida', 15, 183, 7, 7, 48, 'El grito de el mago', 'Animación', 123, datetime.date(2019, 3, 24), 48, 'Xin Tan', 83),
#  (46, 'Omar Cruz', 68, 46, 86, 86, 75, 'La odisea de el castillo', 'Documental', 120, datetime.date(1992, 4, 19), 75, 'Akira Duarte', 90),
#  (46, 'Omar Cruz', 68, 46, 196, 196, 143, 'El camino hacia el jardín', 'Animación', 117, datetime.date(1981, 11, 2), 143, 'Ximena Kumar', 68),
#  (28, 'Omar Petrov', 57, 28, 79, 79, 172, 'La escalada de la amistad', 'Documental', 121, datetime.date(1980, 2, 14), 172, 'Hanako Ramos', 54),
#  (28, 'Omar Petrov', 57, 28, 78, 78, 101, 'El despertar de el guardián', 'Fantasía', 94, datetime.date(1972, 1, 28), 101, 'Mikhail Pacheco', 40),
#  (11, 'Omar Yilmaz', 45, 11, 190, 190, 126, 'El arco iris de la caída', 'Documental', 142, datetime.date(1971, 4, 18), 126, 'Katarina Henriquez', 51),
#  (11, 'Omar Yilmaz', 45, 11, 86, 86, 75, 'La odisea de el castillo', 'Documental', 120, datetime.date(1992, 4, 19), 75, 'Akira Duarte', 90),
#  (11, 'Omar Yilmaz', 45, 11, 33, 33, 65, 'El arco iris de la luz', 'Comedia', 70, datetime.date(1976, 12, 24), 65, 'Umar Qian', 90),
#  (11, 'Omar Yilmaz', 45, 11, 286, 286, 4, 'La llave de la princesa', 'Comedia', 131, datetime.date(1988, 1, 26), 4, 'Oscar Rocha', 74),
#  (11, 'Omar Yilmaz', 45, 11, 271, 271, 84, 'El caballero de la esperanza', 'Acción', 130, datetime.date(1992, 3, 18), 84, 'Parvati Vieira', 73),
#  (11, 'Omar Yilmaz', 45, 11, 153, 153, 151, 'La sombra de la flor', 'Musical', 109, datetime.date(1980, 1, 27), 151, 'Valeria Borges', 32),
#  (11, 'Omar Yilmaz', 45, 11, 204, 204, 197, 'El tesoro escondido de el valle', 'Ciencia ficción', 107, datetime.date(1974, 9, 27), 197, 'Yuri Wu', 73),
#  (11, 'Omar Yilmaz', 45, 11, 294, 294, 151, 'El castillo de la luz', 'Romance', 128, datetime.date(2017, 10, 31), 151, 'Valeria Borges', 32),
#  (11, 'Omar Yilmaz', 45, 11, 90, 90, 133, 'El lamento de la despedida', 'Musical', 79, datetime.date(2000, 4, 2), 133, 'Wang Yamamoto', 41),
#  (58, 'Orhan Oliveira', 24, 58, 179, 179, 166, 'La maldición de el unicornio', 'Documental', 118, datetime.date(2015, 5, 1), 166, 'Qiu Rocha', 71),
#  (58, 'Orhan Oliveira', 24, 58, 200, 200, 153, 'La leyenda perdida de la montaña', 'Drama', 75, datetime.date(1994, 4, 21), 153, 'Chidike Yamamoto', 73),
#  (58, 'Orhan Oliveira', 24, 58, 228, 228, 118, 'La estirpe de el mar', 'Fantasía', 99, datetime.date(2003, 1, 2), 118, 'Chidike Ramos', 86),
#  (110, 'Oscar Abadi', 36, 110, 298, 298, 147, 'La travesía sin retorno de el perdón', 'Terror', 144, datetime.date(1974, 1, 19), 147, 'Umar Pereira', 66),
#  (110, 'Oscar Abadi', 36, 110, 47, 47, 39, 'La búsqueda de el destino', 'Western', 108, datetime.date(1994, 5, 2), 39, 'Zoya Queiroz', 90),
#  (110, 'Oscar Abadi', 36, 110, 238, 238, 146, 'La misión de el amor', 'Animación', 133, datetime.date(2018, 5, 29), 146, 'Zoya Zambrano', 81),
#  (110, 'Oscar Abadi', 36, 110, 46, 46, 30, 'La canción de la guerra', 'Fantasía', 95, datetime.date(1972, 2, 5), 30, 'Jin Carvalho', 71),
#  (1, 'Oscar Almeida', 64, 1, 101, 101, 76, 'El cuento de hadas de el tesoro', 'Ciencia ficción', 89, datetime.date(2003, 8, 14), 76, 'Jasmin Quintana', 71),
#  (1, 'Oscar Almeida', 64, 1, 238, 238, 146, 'La misión de el amor', 'Animación', 133, datetime.date(2018, 5, 29), 146, 'Zoya Zambrano', 81),
#  (172, 'Oscar Ortega', 21, 172, 125, 125, 49, 'El descubrimiento de la aldea', 'Western', 108, datetime.date(1975, 12, 12), 49, 'Tatjana Petrov', 39),
#  (172, 'Oscar Ortega', 21, 172, 225, 225, 118, 'La metamorfosis de la academia', 'Western', 85, datetime.date(1993, 1, 3), 118, 'Chidike Ramos', 86),
#  (72, 'Parvati Abadi', 15, 72, 279, 279, 147, 'La senda de el mito', 'Musical', 94, datetime.date(1999, 8, 13), 147, 'Umar Pereira', 66),
#  (72, 'Parvati Abadi', 15, 72, 235, 235, 177, 'La resurrección de el castillo', 'Drama', 116, datetime.date(1989, 12, 7), 177, 'Beatriz Kumar', 82),
#  (148, 'Parvati Xia', 59, 148, 251, 251, 124, 'La fuga de la expedición', 'Fantasía', 116, datetime.date(2019, 8, 20), 124, 'Parvati Etxebarria', 57),
#  (148, 'Parvati Xia', 59, 148, 148, 148, 140, 'La resurrección de la estrella', 'Comedia', 144, datetime.date(2009, 11, 29), 140, 'Valeria Xu', 87),
#  (148, 'Parvati Xia', 59, 148, 195, 195, 55, 'La misión de el puente', 'Aventura', 74, datetime.date(1990, 4, 24), 55, 'Ursula Duarte', 42),
#  (196, 'Parvati Xu', 37, 196, 248, 248, 188, 'El destino de el camino', 'Ciencia ficción', 129, datetime.date(2023, 11, 12), 188, 'Jin Tan', 80),
#  (182, 'Pilar Mendes', 23, 182, 69, 69, 64, 'El regreso de el muro', 'Aventura', 113, datetime.date(1981, 4, 15), 64, 'Aarav Mendes', 32),
#  (182, 'Pilar Mendes', 23, 182, 274, 274, 104, 'El despertar de la oscuridad', 'Drama', 75, datetime.date(1966, 4, 28), 104, 'Vivek Goncalves', 63),
#  (182, 'Pilar Mendes', 23, 182, 241, 241, 94, 'La doncella de la traición', 'Drama', 127, datetime.date(2002, 5, 15), 94, 'Gustavo Santana', 54),
#  (55, 'Qiu Almeida', 15, 55, 99, 99, 198, 'La fuente de el fuego', 'Comedia', 101, datetime.date(1982, 3, 28), 198, 'Rania Figueiredo', 30),
#  (55, 'Qiu Almeida', 15, 55, 213, 213, 27, 'La venganza de la salvación', 'Musical', 103, datetime.date(1962, 1, 28), 27, 'Wilhelmina Quintana', 90),
#  (133, 'Qiu Ivanov', 69, 133, 260, 260, 74, 'La metamorfosis de la leyenda', 'Terror', 121, datetime.date(2012, 7, 12), 74, 'Aarav Nguyen', 33),
# ...
#  (100, 'Tatjana Wu', 31, 100, 225, 225, 118, 'La metamorfosis de la academia', 'Western', 85, datetime.date(1993, 1, 3), 118, 'Chidike Ramos', 86),
#  (100, 'Tatjana Wu', 31, 100, 246, 246, 29, 'El misterio de el mago', 'Animación', 107, datetime.date(2018, 1, 31), 29, 'Xin Zhang', 41),
#  (162, 'Theresa Correia', 60, 162, 231, 231, 95, 'La fuga de la estrella fugaz', 'Terror', 112, datetime.date(2003, 6, 21), 95, 'Yusef Ortega', 86),
#  (162, 'Theresa Correia', 60, 162, 235, 235, 177, 'La resurrección de el castillo', 'Drama', 116, datetime.date(1989, 12, 7), 177, 'Beatriz Kumar', 82),
#  (162, 'Theresa Correia', 60, 162, 52, 52, 156, 'El lamento de la oscuridad', 'Aventura', 87, datetime.date(1960, 5, 29), 156, 'Wan Gao', 84),
#  (153, 'Theresa Figueiredo', 47, 153, 46, 46, 30, 'La canción de la guerra', 'Fantasía', 95, datetime.date(1972, 2, 5), 30, 'Jin Carvalho', 71),
#  (153, 'Theresa Figueiredo', 47, 153, 290, 290, 17, 'La leyenda de la profecía', 'Acción', 90, datetime.date(2001, 1, 2), 17, 'Umberto Bianchi', 31),
#  (21, 'Theresa Quintana', 47, 21, 159, 159, 65, 'El caballero de el enigma', 'Terror', 74, datetime.date(1966, 12, 28), 65, 'Umar Qian', 90),
#  (21, 'Theresa Quintana', 47, 21, 266, 266, 78, 'El refugio de la leyenda', 'Ciencia ficción', 138, datetime.date(2019, 9, 8), 78, 'Wang Abadi', 66),
#  (21, 'Theresa Quintana', 47, 21, 74, 74, 83, 'La búsqueda del tesoro de el descubrimiento', 'Misterio', 138, datetime.date(2004, 2, 7), 83, 'Vivek Zapata', 68),
#  (88, 'Umar Estevez', 40, 88, 215, 215, 73, 'El grito de la selva', 'Musical', 105, datetime.date(1985, 9, 23), 73, 'Wang Borges', 40),
#  (88, 'Umar Estevez', 40, 88, 285, 285, 14, 'El hechizo de la mariposa', 'Suspense', 113, datetime.date(1997, 1, 12), 14, 'Pilar Pereira', 36),
#  (88, 'Umar Estevez', 40, 88, 15, 15, 111, 'Las aventuras de el encuentro', 'Aventura', 136, datetime.date(2012, 5, 4), 111, 'Sakura Qian', 88),
#  (88, 'Umar Estevez', 40, 88, 55, 55, 23, 'La travesía sin retorno de la desgracia', 'Aventura', 108, datetime.date(2006, 6, 20), 23, 'Yusef Figueiredo', 35),
#  (88, 'Umar Estevez', 40, 88, 51, 51, 9, 'La resurrección de el hechicero', 'Aventura', 83, datetime.date(2008, 3, 19), 9, 'Fadhila Fernandes', 31),
#  (186, 'Umar Ferreira', 20, 186, 184, 184, 138, 'El último viaje de el rincón', 'Comedia', 136, datetime.date(2011, 2, 3), 138, 'Patricia Petrov', 83),
#  (186, 'Umar Ferreira', 20, 186, 125, 125, 49, 'El descubrimiento de la aldea', 'Western', 108, datetime.date(1975, 12, 12), 49, 'Tatjana Petrov', 39),
#  (186, 'Umar Ferreira', 20, 186, 277, 277, 169, 'La travesía del océano de la desgracia', 'Suspense', 133, datetime.date(2022, 12, 19), 169, 'Javier Etxebarria', 63),
#  (186, 'Umar Ferreira', 20, 186, 247, 247, 86, 'El tesoro de la traición', 'Musical', 138, datetime.date(1968, 1, 26), 86, 'Rosa Dutta', 87),
#  (155, 'Umar Janssen', 69, 155, 104, 104, 199, 'La llave de la ciudad', 'Ciencia ficción', 80, datetime.date(1969, 5, 18), 199, 'Zara Teixeira', 88),
#  (85, 'Umberto Henriquez', 65, 85, 299, 299, 167, 'El lamento de el héroe', 'Drama', 100, datetime.date(2018, 12, 21), 167, 'Mina Fernandes', 35),
#  (85, 'Umberto Henriquez', 65, 85, 201, 201, 145, 'El cuento de hadas de la estrella', 'Acción', 109, datetime.date(2015, 2, 7), 145, 'Tatjana Rodriguez', 60),
#  (103, 'Umberto Lopez', 61, 103, 59, 59, 109, 'El ritual de el sacrificio', 'Documental', 108, datetime.date(1962, 2, 1), 109, 'Darius Barros', 43),
#  (103, 'Umberto Lopez', 61, 103, 259, 259, 149, 'La odisea de el amor', 'Comedia', 136, datetime.date(2019, 6, 3), 149, 'Mehmet Tan', 76),
#  (109, 'Ursula Carvalho', 64, 109, 273, 273, 143, 'La resurrección de la cascada', 'Documental', 75, datetime.date(1964, 7, 23), 143, 'Ximena Kumar', 68),
#  (109, 'Ursula Carvalho', 64, 109, 138, 138, 187, 'La travesía del océano de la estrella', 'Romance', 88, datetime.date(1963, 3, 2), 187, 'Khaled Vargas', 32),
#  (109, 'Ursula Carvalho', 64, 109, 219, 219, 129, 'El vuelo de el amor', 'Musical', 101, datetime.date(1975, 8, 14), 129, 'Patricia Ferreira', 66),
#  (109, 'Ursula Carvalho', 64, 109, 203, 203, 32, 'La senda de el cielo', 'Misterio', 114, datetime.date(1997, 6, 16), 32, 'Zoya Bianchi', 33),
#  (109, 'Ursula Carvalho', 64, 109, 110, 110, 98, 'El vuelo mágico de el sueño', 'Musical', 98, datetime.date(2001, 11, 18), 98, 'Tatjana Pacheco', 44),
#  (109, 'Ursula Carvalho', 64, 109, 263, 263, 139, 'La escalada de el renacimiento', 'Misterio', 132, datetime.date(1983, 8, 5), 139, 'Lakshmi Abadi', 77),
#  (114, 'Valentina Hernandez', 56, 114, 212, 212, 22, 'La doncella de el viaje', 'Musical', 107, datetime.date(1990, 2, 2), 22, 'Giovanni Santana', 59),
#  (114, 'Valentina Hernandez', 56, 114, 26, 26, 130, 'La sombra de la estrella', 'Fantasía', 78, datetime.date(1992, 11, 3), 130, 'Zoya Olivares', 34),
#  (34, 'Valeria Nguyen', 22, 34, 206, 206, 196, 'La misión de el enigma', 'Suspense', 112, datetime.date(1976, 2, 6), 196, 'Zafar Kawaguchi', 87),
#  (34, 'Valeria Nguyen', 22, 34, 71, 71, 194, 'El viajero de la sirena', 'Romance', 79, datetime.date(1975, 10, 24), 194, 'Elena Pacheco', 53),
#  (34, 'Valeria Nguyen', 22, 34, 83, 83, 27, 'La fuga de la profecía', 'Western', 98, datetime.date(1997, 12, 6), 27, 'Wilhelmina Quintana', 90),
#  (181, 'Valeria Teixeira', 50, 181, 186, 186, 154, 'La danza macabra de la ola', 'Acción', 126, datetime.date(1965, 6, 12), 154, 'Hanako Gomes', 78),
#  (27, 'Valeria Uchoa', 23, 27, 84, 84, 99, 'La trampa de la reina', 'Acción', 100, datetime.date(1973, 6, 19), 99, 'Fadhila Qian', 45),
#  (27, 'Valeria Uchoa', 23, 27, 36, 36, 180, 'El arco iris de la neblina', 'Terror', 121, datetime.date(1968, 5, 14), 180, 'Ursula Yamamoto', 59),
#  (27, 'Valeria Uchoa', 23, 27, 111, 111, 91, 'La búsqueda de la sirena', 'Aventura', 95, datetime.date(1967, 5, 6), 91, 'Khaled Oliveira', 67),
#  (27, 'Valeria Uchoa', 23, 27, 257, 257, 79, 'La metamorfosis de el abismo', 'Suspense', 137, datetime.date(2004, 3, 31), 79, 'Omar Barros', 58),
#  (75, 'Vivek Bianchi', 22, 75, 131, 131, 186, 'El príncipe de la fortuna', 'Romance', 79, datetime.date(2000, 9, 24), 186, 'Nina Ramos', 38),
#  (75, 'Vivek Bianchi', 22, 75, 136, 136, 124, 'La historia de el sacrificio', 'Acción', 93, datetime.date(1997, 6, 21), 124, 'Parvati Etxebarria', 57),
#  (75, 'Vivek Bianchi', 22, 75, 9, 9, 54, 'La trampa de la bienvenida', 'Aventura', 121, datetime.date(1982, 11, 16), 54, 'Chiyoko Teixeira', 34),
#  (75, 'Vivek Bianchi', 22, 75, 76, 76, 160, 'La maldición del vampiro de el renacer', 'Documental', 128, datetime.date(1994, 10, 15), 160, 'Lakshmi Kawaguchi', 84),
#  (86, 'Vivek Vieira', 28, 86, 47, 47, 39, 'La búsqueda de el destino', 'Western', 108, datetime.date(1994, 5, 2), 39, 'Zoya Queiroz', 90),
#  (86, 'Vivek Vieira', 28, 86, 263, 263, 139, 'La escalada de el renacimiento', 'Misterio', 132, datetime.date(1983, 8, 5), 139, 'Lakshmi Abadi', 77),
#  (197, 'Vivek Zambrano', 32, 197, 137, 137, 38, 'El hechizo de la fortuna', 'Western', 109, datetime.date(2005, 1, 31), 38, 'Xavier Uchoa', 73),
#  (199, 'Vivek Zhang', 61, 199, 224, 224, 97, 'El amanecer de la traición', 'Misterio', 118, datetime.date(1969, 7, 27), 97, 'Aarav Lopes', 63),
#  (199, 'Vivek Zhang', 61, 199, 143, 143, 194, 'El hechizo de la estrella', 'Comedia', 150, datetime.date(1978, 7, 23), 194, 'Elena Pacheco', 53),
#  (199, 'Vivek Zhang', 61, 199, 75, 75, 159, 'La estrella fugaz de el amor', 'Acción', 130, datetime.date(1987, 9, 23), 159, 'Oscar Quintana', 42),
#  (111, 'Wang Henriquez', 23, 111, 152, 152, 185, 'El regreso de el héroe', 'Suspense', 94, datetime.date(1970, 12, 18), 185, 'Wan Correia', 32),
#  (111, 'Wang Henriquez', 23, 111, 69, 69, 64, 'El regreso de el muro', 'Aventura', 113, datetime.date(1981, 4, 15), 64, 'Aarav Mendes', 32),
#  (3, 'Wilhelmina Petrov', 51, 3, 165, 165, 46, 'El descubrimiento de el sacrificio', 'Comedia', 127, datetime.date(1976, 3, 27), 46, 'Zoya Santana', 90),
#  (139, 'Xavier Abadi', 30, 139, 80, 80, 161, 'La maldición de la traición', 'Suspense', 77, datetime.date(1967, 3, 31), 161, 'Rashid Mendes', 69),
#  (139, 'Xavier Abadi', 30, 139, 210, 210, 67, 'El misterio de la pesadilla', 'Suspense', 116, datetime.date(1996, 10, 31), 67, 'Khaled Dutta', 77),
#  (139, 'Xavier Abadi', 30, 139, 116, 116, 88, 'El ritual de la venganza', 'Documental', 138, datetime.date(1993, 7, 24), 88, 'Chidike Yan', 56),
#  (139, 'Xavier Abadi', 30, 139, 289, 289, 24, 'El lamento de la ola', 'Western', 86, datetime.date(1984, 10, 4), 24, 'Aarav Queiroz', 51),
#  (139, 'Xavier Abadi', 30, 139, 138, 138, 187, 'La travesía del océano de la estrella', 'Romance', 88, datetime.date(1963, 3, 2), 187, 'Khaled Vargas', 32),
#  (38, 'Xavier Gomes', 43, 38, 209, 209, 100, 'La escalada de la aldea', 'Drama', 77, datetime.date(1973, 8, 11), 100, 'Abdullah Ramos', 72),
#  (158, 'Xavier Olivares', 67, 158, 256, 256, 37, 'La danza de la estrella', 'Suspense', 95, datetime.date(1981, 11, 28), 37, 'Wan Vieira', 46),
#  (158, 'Xavier Olivares', 67, 158, 115, 115, 16, 'La escalada de la selva', 'Romance', 96, datetime.date(1980, 2, 13), 16, 'Hiroko Xu', 87),
#  (142, 'Xavier Petrov', 36, 142, 166, 166, 168, 'La llegada de la promesa', 'Documental', 95, datetime.date(2014, 11, 10), 168, 'Ilya Olivares', 41),
#  (142, 'Xavier Petrov', 36, 142, 157, 157, 163, 'La resurrección de la gárgola', 'Terror', 94, datetime.date(2017, 11, 27), 163, 'Javier Queiroz', 39),
#  (142, 'Xavier Petrov', 36, 142, 200, 200, 153, 'La leyenda perdida de la montaña', 'Drama', 75, datetime.date(1994, 4, 21), 153, 'Chidike Yamamoto', 73),
#  (45, 'Xavier Ramos', 38, 45, 51, 51, 9, 'La resurrección de el hechicero', 'Aventura', 83, datetime.date(2008, 3, 19), 9, 'Fadhila Fernandes', 31),
#  (18, 'Ximena Goncalves', 24, 18, 16, 16, 28, 'La travesía del océano de la gárgola', 'Drama', 148, datetime.date(1974, 1, 14), 28, 'Oscar Teixeira', 59),
#  (18, 'Ximena Goncalves', 24, 18, 261, 261, 19, 'El último viaje de el dragón', 'Animación', 145, datetime.date(1985, 3, 19), 19, 'Tatiana Estevez', 81),
#  (18, 'Ximena Goncalves', 24, 18, 45, 45, 199, 'La redención de la nube', 'Fantasía', 98, datetime.date(1971, 4, 25), 199, 'Zara Teixeira', 88),
#  (146, 'Ximena Petrov', 37, 146, 172, 172, 62, 'El grito de el renacer', 'Aventura', 125, datetime.date(1999, 11, 17), 62, 'Chiyoko Xia', 42),
#  (146, 'Ximena Petrov', 37, 146, 254, 254, 64, 'El amanecer de el viaje', 'Romance', 115, datetime.date(1974, 11, 9), 64, 'Aarav Mendes', 32),
#  (129, 'Ximena Santana', 21, 129, 141, 141, 92, 'El descubrimiento de el rincón', 'Terror', 74, datetime.date(1961, 6, 22), 92, 'Sakura Lopez', 78),
#  (129, 'Ximena Santana', 21, 129, 237, 237, 162, 'El amanecer de la ley', 'Documental', 130, datetime.date(2022, 4, 30), 162, 'Valeria Xu', 45),
#  (7, 'Xin Iglesias', 20, 7, 95, 95, 170, 'La fortuna de el muro', 'Drama', 138, datetime.date(1975, 2, 22), 170, 'Giovanni Vargas', 50),
#  (7, 'Xin Iglesias', 20, 7, 233, 233, 32, 'La travesía sin retorno de la trampa', 'Musical', 95, datetime.date(1988, 10, 30), 32, 'Zoya Bianchi', 33),
#  (113, 'Xin Zambrano', 24, 113, 274, 274, 104, 'El despertar de la oscuridad', 'Drama', 75, datetime.date(1966, 4, 28), 104, 'Vivek Goncalves', 63),
#  (117, 'Yasmin Ferreira', 61, 117, 88, 88, 121, 'La búsqueda de la desgracia', 'Misterio', 91, datetime.date(1974, 2, 2), 121, 'Katarina Iglesias', 32),
#  (117, 'Yasmin Ferreira', 61, 117, 106, 106, 178, 'La batalla de la cripta', 'Documental', 126, datetime.date(2009, 5, 12), 178, 'Qiu Rodriguez', 66),
#  (117, 'Yasmin Ferreira', 61, 117, 50, 50, 172, 'El guardián de la bailarina', 'Romance', 86, datetime.date(2004, 3, 9), 172, 'Hanako Ramos', 54),
#  (36, 'Yuri Gomes', 31, 36, 79, 79, 172, 'La escalada de la amistad', 'Documental', 121, datetime.date(1980, 2, 14), 172, 'Hanako Ramos', 54),
#  (36, 'Yuri Gomes', 31, 36, 197, 197, 39, 'La danza macabra de la aventura', 'Ciencia ficción', 149, datetime.date(1983, 5, 27), 39, 'Zoya Queiroz', 90),
#  (180, 'Yuri Queiroz', 38, 180, 15, 15, 111, 'Las aventuras de el encuentro', 'Aventura', 136, datetime.date(2012, 5, 4), 111, 'Sakura Qian', 88),
#  (180, 'Yuri Queiroz', 38, 180, 231, 231, 95, 'La fuga de la estrella fugaz', 'Terror', 112, datetime.date(2003, 6, 21), 95, 'Yusef Ortega', 86),
#  (180, 'Yuri Queiroz', 38, 180, 4, 4, 184, 'La travesura de la estrella', 'Terror', 136, datetime.date(1961, 5, 13), 184, 'Samir Janssen', 33),
#  (59, 'Yusef Iglesias', 57, 59, 236, 236, 71, 'El príncipe de la amistad', 'Musical', 123, datetime.date(1983, 10, 15), 71, 'Leticia Martinez', 53),
#  (59, 'Yusef Iglesias', 57, 59, 90, 90, 133, 'El lamento de la despedida', 'Musical', 79, datetime.date(2000, 4, 2), 133, 'Wang Yamamoto', 41),
#  (2, 'Yusef Sousa', 51, 2, 10, 10, 197, 'La canción de la caza', 'Ciencia ficción', 89, datetime.date(1963, 3, 30), 197, 'Yuri Wu', 73),
#  (2, 'Yusef Sousa', 51, 2, 108, 108, 156, 'El resurgimiento de la bienvenida', 'Terror', 87, datetime.date(1998, 7, 26), 156, 'Wan Gao', 84),
#  (136, 'Yusef Uchoa', 27, 136, 141, 141, 92, 'El descubrimiento de el rincón', 'Terror', 74, datetime.date(1961, 6, 22), 92, 'Sakura Lopez', 78),
#  (179, 'Zara Goncalves', 22, 179, 128, 128, 19, 'El secreto oscuro de el cielo', 'Romance', 150, datetime.date(1981, 3, 9), 19, 'Tatiana Estevez', 81),
#  (179, 'Zara Goncalves', 22, 179, 107, 107, 56, 'El vuelo de el peligro', 'Acción', 137, datetime.date(2003, 10, 20), 56, 'Akira Rocha', 34),
#  (179, 'Zara Goncalves', 22, 179, 182, 182, 189, 'La doncella de la montaña', 'Comedia', 137, datetime.date(1961, 7, 25), 189, 'Khaled Gomes', 31),
#  (130, 'Zara Jimenez', 43, 130, 7, 7, 48, 'El grito de el mago', 'Animación', 123, datetime.date(2019, 3, 24), 48, 'Xin Tan', 83),
#  (130, 'Zara Jimenez', 43, 130, 123, 123, 147, 'La misión de el viajero', 'Western', 137, datetime.date(2009, 1, 23), 147, 'Umar Pereira', 66),
#  (130, 'Zara Jimenez', 43, 130, 118, 118, 3, 'La búsqueda del tesoro de el unicornio', 'Aventura', 148, datetime.date(1980, 8, 15), 3, 'Leticia Quintana', 33),
#  (130, 'Zara Jimenez', 43, 130, 90, 90, 133, 'El lamento de la despedida', 'Musical', 79, datetime.date(2000, 4, 2), 133, 'Wang Yamamoto', 41),
#  (130, 'Zara Jimenez', 43, 130, 230, 230, 13, 'El secreto oscuro de la ciudad', 'Fantasía', 120, datetime.date(1998, 8, 15), 13, 'Orhan Etxebarria', 62),
#  (80, 'Zara Nunes', 17, 80, 57, 57, 91, 'El misterio de el cielo', 'Romance', 131, datetime.date(2021, 1, 10), 91, 'Khaled Oliveira', 67),
#  (80, 'Zara Nunes', 17, 80, 225, 225, 118, 'La metamorfosis de la academia', 'Western', 85, datetime.date(1993, 1, 3), 118, 'Chidike Ramos', 86),
#  (198, 'Zara Urbina', 19, 198, 227, 227, 111, 'La travesura de la aventura', 'Drama', 101, datetime.date(1981, 4, 2), 111, 'Sakura Qian', 88),
#  (198, 'Zara Urbina', 19, 198, 57, 57, 91, 'El misterio de el cielo', 'Romance', 131, datetime.date(2021, 1, 10), 91, 'Khaled Oliveira', 67),
#  (43, 'Zara Xu', 48, 43, 264, 264, 112, 'La rebelión de el faro', 'Ciencia ficción', 130, datetime.date(1970, 4, 11), 112, 'Alessandro Lopez', 73),
#  (43, 'Zara Xu', 48, 43, 169, 169, 91, 'La doncella de la corona', 'Documental', 96, datetime.date(2021, 11, 26), 91, 'Khaled Oliveira', 67),
#  (43, 'Zara Xu', 48, 43, 11, 11, 97, 'La danza macabra de la oscuridad', 'Documental', 133, datetime.date(1961, 3, 3), 97, 'Aarav Lopes', 63),
#  (43, 'Zara Xu', 48, 43, 176, 176, 137, 'Las aventuras de el río', 'Terror', 135, datetime.date(1989, 10, 27), 137, 'Samir Carvalho', 42),
#  (131, 'Zoya Quintana', 33, 131, 42, 42, 36, 'La canción de el amanecer', 'Romance', 78, datetime.date(1973, 1, 15), 36, 'Xavier Vieira', 37),
#  (115, 'Zoya Yilmaz', 36, 115, 253, 253, 54, 'Las aventuras de la guerra', 'Acción', 138, datetime.date(1964, 12, 29), 54, 'Chiyoko Teixeira', 34),
#  (115, 'Zoya Yilmaz', 36, 115, 39, 39, 114, 'El príncipe de el destino', 'Musical', 120, datetime.date(2022, 4, 1), 114, 'Valentina Mendes', 44),
#  (115, 'Zoya Yilmaz', 36, 115, 45, 45, 199, 'La redención de la nube', 'Fantasía', 98, datetime.date(1971, 4, 25), 199, 'Zara Teixeira', 88)]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cafe4e99-499e-4e36-b9fd-48e2d31e0196' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
